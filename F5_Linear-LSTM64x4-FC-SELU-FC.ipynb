# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5_Linear-LSTM64x4-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 1000
evaluate_num        = 128
focus_min           = 0.8

# %%
class net_test(torch.nn.Module):
    def __init__(self, **kwargs):
        super(net_test, self).__init__()
        self.embedding = torch.nn.Linear(5, 64, bias=False)
        self.lstm = torch.nn.LSTM(64, 64, num_layers=4, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(64*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
model = net_test()
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (embedding): Linear(in_features=5, out_features=64, bias=False)
#   (lstm): LSTM(64, 64, num_layers=4, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=128, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 364897 0

# %%
# state_dict = torch.load(f'models/{fname}_best.pth')
# model.load_state_dict(state_dict)

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.710156</td>
#       <td>4.357627</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.451651</td>
#       <td>1.387135</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.112430</td>
#       <td>1.095605</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1
td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.200023</td>
#       <td>0.227187</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.203074</td>
#       <td>0.229705</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.200297</td>
#       <td>0.226006</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.198293</td>
#       <td>0.224
# Better model found at epoch 0 with valid_loss value: 0.23620861768722534.
# Epoch 10: reducing lr to 8.581716771801779e-05
# Epoch 20: reducing lr to 0.00018802998854129706
# Epoch 30: reducing lr to 0.00019687540232975727
# Epoch 40: reducing lr to 0.0001784121995859993
# Better model found at epoch 46 with valid_loss value: 0.23544171452522278.
# Better model found at epoch 47 with valid_loss value: 0.23479674756526947.
# Epoch 50: reducing lr to 0.00014639098138880284
# Better model found at epoch 52 with valid_loss value: 0.23474687337875366.
# Better model found at epoch 54 with valid_loss value: 0.23372340202331543.
# Better model found at epoch 57 with valid_loss value: 0.23071160912513733.
# Epoch 60: reducing lr to 0.00010634853006612538
# Better model found at epoch 62 with valid_loss value: 0.2286914736032486.
# Better model found at epoch 66 with valid_loss value: 0.22826208174228668.
# Better model found at epoch 67 with valid_loss value: 0.2281244844198227.
# Better model found at epoch 69 with valid_loss value: 0.22509413957595825.
# Epoch 70: reducing lr to 6.520850740902317e-05
# Better model found at epoch 73 with valid_loss value: 0.22454985976219177.
# Better model found at epoch 75 with valid_loss value: 0.22389081120491028.
# Better model found at epoch 77 with valid_loss value: 0.22295841574668884.
# Better model found at epoch 79 with valid_loss value: 0.22265107929706573.
# Epoch 80: reducing lr to 3.0084440781536825e-05
# Better model found at epoch 83 with valid_loss value: 0.22239768505096436.
# Better model found at epoch 85 with valid_loss value: 0.22233331203460693.
# Better model found at epoch 86 with valid_loss value: 0.22215314209461212.
# Better model found at epoch 87 with valid_loss value: 0.22213715314865112.
# Better model found at epoch 88 with valid_loss value: 0.22161787748336792.
# Better model found at epoch 90 with valid_loss value: 0.22140175104141235.
# Epoch 90: reducing lr to 7.049580994910807e-06
# Better model found at epoch 94 with valid_loss value: 0.2213016152381897.
# Better model found at epoch 96 with valid_loss value: 0.22128409147262573.
# Better model found at epoch 97 with valid_loss value: 0.22127912938594818.
# Better model found at epoch 98 with valid_loss value: 0.2212790995836258.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.19013653622298946 0.22076987754553556

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 51/51 [00:01<00:00, 28.26it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
