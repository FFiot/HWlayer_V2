# %% [markdown]
# Reference
# * https://www.kaggle.com/hirayukis/pytorch-lstm-cv-0-1942-lb-0-193
#   * 242,5729
# * https://www.kaggle.com/dienhoa/ventillator-fastai-lb-0-168-no-kfolds-no-blend?scriptVersionId=78176083
#   * 1051,2501

# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchsummary import summary

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_base import evaluate_build, focus_build
from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_torch import torch_valid, torch_predict

# %%
fname = 'F25_RobustScaler_(E128_F60_FC25)_LSTM(500-400-300-200)_(FC-SELU-FC)'
evaluate_num = 128
focus_min = 0.6
epoch_num = 200
batch_size = 100

# %%
class RNNModel(nn.Module):
    def __init__(self, evaluate_focus_list):
        super().__init__()
        hidden = [500, 400, 300, 200]
        self.hw_layer = hw_layer(evaluate_focus_list)
        self.fc = nn.Linear(self.hw_layer.channels, 25)
        self.lstm1 = nn.LSTM(25, hidden[0],
                             batch_first=True, bidirectional=True)
        self.lstm2 = nn.LSTM(2 * hidden[0], hidden[1],
                             batch_first=True, bidirectional=True)
        self.lstm3 = nn.LSTM(2 * hidden[1], hidden[2],
                             batch_first=True, bidirectional=True)
        self.lstm4 = nn.LSTM(2 * hidden[2], hidden[3],
                             batch_first=True, bidirectional=True)
        self.fc1 = nn.Linear(2 * hidden[3], 50)
        self.selu = nn.SELU()
        self.fc2 = nn.Linear(50, 1)
        self._reinitialize()

    def _reinitialize(self):
        """
        Tensorflow/Keras-like initialization
        """
        for name, p in self.named_parameters():
            if 'lstm' in name:
                if 'weight_ih' in name:
                    nn.init.xavier_uniform_(p.data)
                elif 'weight_hh' in name:
                    nn.init.orthogonal_(p.data)
                elif 'bias_ih' in name:
                    p.data.fill_(0)
                    # Set forget-gate bias to 1
                    n = p.size(0)
                    p.data[(n // 4):(n // 2)].fill_(1)
                elif 'bias_hh' in name:
                    p.data.fill_(0)
            elif 'fc' in name:
                if 'weight' in name:
                    nn.init.xavier_uniform_(p.data)
                elif 'bias' in name:
                    p.data.fill_(0)

    def forward(self, x):
        x = self.hw_layer(x)
        x = self.fc(x)
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x, _ = self.lstm3(x)
        x, _ = self.lstm4(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)

        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
def add_features(df):
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['cross']= df['u_in']*df['u_out']
    df['cross2']= df['time_step']*df['u_out']
    
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['u_in_lag'] = df['u_in_lag']*df['breath_id_lagsame']
    df['u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['u_in_lag2'] = df['u_in_lag2']*df['breath_id_lag2same']
    df['u_out_lag2'] = df['u_out'].shift(2).fillna(0)
    df['u_out_lag2'] = df['u_out_lag2']*df['breath_id_lag2same']
    #df['u_in_lag'] = df['u_in'].shift(2).fillna(0)
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['RC'] = df['R']+df['C']
    df = pd.get_dummies(df)
    return df

# %%
data_train_df = add_features(data_train_df)
data_test_df = add_features(data_test_df)

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
RS = RobustScaler()
data_train = data_train_df[x_columns].values
data_train = RS.fit_transform(data_train).astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values
data_test = RS.transform(data_test).astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
print(data_train.shape)
# Out:
# (75450, 80, 25)

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

print(len(train_index), len(valid_index))

x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test
# Out:
# 60360 15090

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 22

# %%
evaluate_list = [evaluate_build(x_test[..., i], evaluate_num) for i in range(x_test.shape[-1])]
evaluate_focus_list = []
for evaluate in evaluate_list:
    focus = 1 - (len(evaluate) - 1)/10
    if focus < focus_min:
        focus = focus_min
    evaluate_focus = focus_build(evaluate, focus)
    evaluate_focus_list.append(evaluate_focus)
# Out:
# evaluate_num: 127,focus:0.6000: 127it [00:00, 310.90it/s]
# evaluate_num:  99,focus:0.6000: 99it [00:00, 254.70it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num: 127,focus:0.6000: 127it [00:00, 206.15it/s]
# evaluate_num:  57,focus:0.6000: 57it [00:00, 386.17it/s]
# evaluate_num:  80,focus:0.6000: 80it [00:00, 292.27it/s]
# evaluate_num: 128,focus:0.6000: 128it [00:00, 201.77it/s]
# evaluate_num: 128,focus:0.6000: 128it [00:00, 190.72it/s]
# evaluate_num:  97,focus:0.6000: 97it [00:00, 240.74it/s]
# evaluate_num:  95,focus:0.6000: 95it [00:00, 267.63it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, 2006.84it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]

# %%
model = RNNModel(evaluate_focus_list)
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# RNNModel(
#   (hw_layer): hw_layer(
#     (evaluate_list): ModuleList(
#       (0): Embedding(127, 1)
#       (1): Embedding(99, 1)
#       (2): Embedding(2, 1)
#       (3): Embedding(127, 1)
#       (4): Embedding(57, 1)
#       (5): Embedding(80, 1)
#       (6): Embedding(128, 1)
#       (7): Embedding(128, 1)
#       (8): Embedding(97, 1)
#       (9): Embedding(95, 1)
#       (10): Embedding(2, 1)
#       (11): Embedding(2, 1)
#       (12): Embedding(2, 1)
#       (13): Embedding(2, 1)
#       (14): Embedding(2, 1)
#       (15): Embedding(2, 1)
#       (16): Embedding(2, 1)
#       (17): Embedding(2, 1)
#       (18): Embedding(2, 1)
#       (19): Embedding(2, 1)
#       (20): Embedding(2, 1)
#       (21): Embedding(2, 1)
#       (22): Embedding(2, 1)
#       (23): Embedding(2, 1)
#       (24): Embedding(2, 1)
#     )
#     (focus_list): ModuleList(
#       (0): Embedding(127, 1)
#       (1): Embedding(99, 1)
#       (2): Embedding(2, 1)
#       (3): Embedding(127, 1)
#       (4): Embedding(57, 1)
#       (5): Embedding(80, 1)
#       (6): Embedding(128, 1)
#       (7): Embedding(128, 1)
#       (8): Embedding(97, 1)
#       (9): Embedding(95, 1)
#       (10): Embedding(2, 1)
#       (11): Embedding(2, 1)
#       (12): Embedding(2, 1)
#       (13): Embedding(2, 1)
#       (14): Embedding(2, 1)
#       (15): Embedding(2, 1)
#       (16): Embedding(2, 1)
#       (17): Embedding(2, 1)
#       (18): Embedding(2, 1)
#       (19): Embedding(2, 1)
#       (20): Embedding(2, 1)
#       (21): Embedding(2, 1)
#       (22): Embedding(2, 1)
#       (23): Embedding(2, 1)
#       (24): Embedding(2, 1)
#     )
#   )
#   (fc): Linear(in_features=970, out_features=25, bias=True)
#   (lstm1): LSTM(25, 500, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(1000, 400, batch_first=True, bidirectional=True)
#   (lstm3): LSTM(800, 300, batch_first=True, bidirectional=True)
#   (lstm4): LSTM(600, 200, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=400, out_features=50, bias=True)
#   (selu): SELU()
#   (fc2): Linear(in_features=50, out_features=1, bias=True)
# )
# 10566776 1940

# %%
def train_submission(epoch_num, batch_size):
    dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size)
    learn = Learner(dataLoads, model, loss_func=L1LossFlat())
    learn.lr_find()
    learn.fit_one_cycle(epoch_num, lr_max=2e-3, cbs=[ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10),
                                                     SaveModelCallback(monitor='valid_loss', fname=f'{fname}_B{batch_size}_best')])
    
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    state_dict = torch.load(f'models/{fname}_B{batch_size}_best.pth')
    model.load_state_dict(state_dict)

    loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size, to_device=device)
    valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size, to_device=device)

    print(loss, valid_loss)

    predict = torch_predict([model.to(device)], x_test, batch_size, to_device=device)
    predict = np.reshape(predict, (-1))

    df = pd.read_csv('Database/sample_submission.csv', index_col=0)
    df['pressure'] = predict

    df.to_csv(f'Submission/{fname}_B{batch_size}.csv')

# %%
train_submission(epoch_num, batch_size)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.412038</td>
#       <td>1.314388</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.089065</td>
#       <td>1.038242</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.932152</td>
#       <td>0.922154</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.876958</td>
#       <td>0.836968</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.809623</td>
#       <td>0.784777</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.762492</td>
#       <td>0.763870</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.741920</td>
#       <td>0.748556</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.698249</td>
#       <td>0.715388</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.659498</td>
#       <td>0.679854</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.568962</td>
#       <td>0.534226</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.544830</td>
#       <td>0.612016</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.497560</td>
#       <td>0.503221</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.494906</td>
#       <td>0.473431</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.470350</td>
#       <td>0.465747</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.457444</td>
#       <td>0.457839</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.439090</td>
#       <td>0.439443</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.429009</td>
#       <td>0.447687</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.418048</td>
#       <td>0.421108</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.409150</td>
#       <td>0.408434</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.405843</td>
#       <td>0.393052</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.401567</td>
#       <td>0.394401</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.374774</td>
#       <td>0.377915</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.369951</td>
#       <td>0.370425</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.363411</td>
#       <td>0.358992</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.371117</td>
#       <td>0.357645</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.357558</td>
#       <td>0.363945</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.357382</td>
#       <td>0.456825</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.349359</td>
#       <td>0.347455</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.345025</td>
#       <td>0.344067</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.325585</td>
#       <td>0.331563</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.328174</td>
#       <td>0.313092</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.322510</td>
#       <td>0.331913</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.312956</td>
#       <td>0.315459</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.317815</td>
#       <td>0.316130</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.340696</td>
#       <td>0.327480</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.300282</td>
#       <td>0.310342</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.299787</td>
#       <td>0.298339</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.293016</td>
#       <td>0.297119</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.306983</td>
#       <td>0.346936</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.302926</td>
#       <td>0.298510</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.288795</td>
#       <td>0.362108</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.290007</td>
#       <td>0.314107</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.278638</td>
#       <td>0.282305</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.262555</td>
#       <td>0.280212</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.263815</td>
#       <td>0.271954</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.255426</td>
#       <td>0.258265</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.262672</td>
#       <td>0.267751</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.250089</td>
#       <td>0.261533</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.290068</td>
#       <td>0.283942</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.254396</td>
#       <td>0.260600</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.255789</td>
#       <td>0.258054</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.260933</td>
#       <td>0.269714</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.246140</td>
#       <td>0.258612</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.245307</td>
#       <td>0.271238</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.302864</td>
#       <td>0.306183</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.247249</td>
#       <td>0.248037</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.240491</td>
#       <td>0.256518</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.226924</td>
#       <td>0.234487</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.223641</td>
#       <td>0.237212</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.228750</td>
#       <td>0.241412</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.223120</td>
#       <td>0.258952</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.210595</td>
#       <td>0.250187</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.212979</td>
#       <td>0.230317</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.227629</td>
#       <td>0.243148</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.205588</td>
#       <td>0.234235</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.204818</td>
#       <td>0.229647</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.213208</td>
#       <td>0.227515</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.203573</td>
#       <td>0.230030</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.210165</td>
#       <td>0.227346</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.196759</td>
#       <td>0.226702</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.193016</td>
#       <td>0.230073</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.193003</td>
#       <td>0.219325</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.192058</td>
#       <td>0.214224</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.187315</td>
#       <td>0.212
# Better model found at epoch 0 with valid_loss value: 1.3143882751464844.
# Better model found at epoch 1 with valid_loss value: 1.0382416248321533.
# Better model found at epoch 2 with valid_loss value: 0.9221541881561279.
# Better model found at epoch 3 with valid_loss value: 0.8369681239128113.
# Better model found at epoch 4 with valid_loss value: 0.7847774624824524.
# Better model found at epoch 5 with valid_loss value: 0.7638701796531677.
# Better model found at epoch 6 with valid_loss value: 0.74855637550354.
# Better model found at epoch 7 with valid_loss value: 0.7153875827789307.
# Better model found at epoch 8 with valid_loss value: 0.6798536777496338.
# Better model found at epoch 9 with valid_loss value: 0.5342262983322144.
# Better model found at epoch 11 with valid_loss value: 0.5032205581665039.
# Better model found at epoch 12 with valid_loss value: 0.4734313488006592.
# Better model found at epoch 13 with valid_loss value: 0.4657473564147949.
# Better model found at epoch 14 with valid_loss value: 0.4578392505645752.
# Epoch 14: reducing lr to 4.756454026689867e-05
# Better model found at epoch 15 with valid_loss value: 0.4394434094429016.
# Better model found at epoch 17 with valid_loss value: 0.42110779881477356.
# Better model found at epoch 18 with valid_loss value: 0.40843409299850464.
# Better model found at epoch 19 with valid_loss value: 0.39305248856544495.
# Better model found at epoch 21 with valid_loss value: 0.3779148459434509.
# Better model found at epoch 22 with valid_loss value: 0.37042510509490967.
# Better model found at epoch 23 with valid_loss value: 0.35899242758750916.
# Better model found at epoch 24 with valid_loss value: 0.3576448857784271.
# Epoch 24: reducing lr to 0.00010399001414461563
# Better model found at epoch 27 with valid_loss value: 0.34745508432388306.
# Better model found at epoch 28 with valid_loss value: 0.34406721591949463.
# Better model found at epoch 29 with valid_loss value: 0.33156269788742065.
# Better model found at epoch 30 with valid_loss value: 0.31309211254119873.
# Epoch 34: reducing lr to 0.0001604193095513737
# Better model found at epoch 35 with valid_loss value: 0.310342401266098.
# Better model found at epoch 36 with valid_loss value: 0.29833856225013733.
# Better model found at epoch 37 with valid_loss value: 0.2971188724040985.
# Better model found at epoch 42 with valid_loss value: 0.2823054790496826.
# Better model found at epoch 43 with valid_loss value: 0.28021180629730225.
# Better model found at epoch 44 with valid_loss value: 0.271953821182251.
# Better model found at epoch 45 with valid_loss value: 0.25826504826545715.
# Better model found at epoch 50 with valid_loss value: 0.25805404782295227.
# Epoch 52: reducing lr to 0.00019980289224442102
# Better model found at epoch 55 with valid_loss value: 0.24803708493709564.
# Better model found at epoch 57 with valid_loss value: 0.2344866544008255.
# Better model found at epoch 62 with valid_loss value: 0.23031680285930634.
# Epoch 62: reducing lr to 0.0001963172269862917
# Better model found at epoch 65 with valid_loss value: 0.22964675724506378.
# Better model found at epoch 66 with valid_loss value: 0.2275153398513794.
# Better model found at epoch 68 with valid_loss value: 0.2273464947938919.
# Better model found at epoch 69 with valid_loss value: 0.226701557636261.
# Better model found at epoch 71 with valid_loss value: 0.21932454407215118.
# Better model found at epoch 72 with valid_loss value: 0.21422410011291504.
# Epoch 72: reducing lr to 0.00018862207835967495
# Better model found at epoch 73 with valid_loss value: 0.21280187368392944.
# Better model found at epoch 75 with valid_loss value: 0.20533902943134308.
# Epoch 82: reducing lr to 0.000177053759108705
# Better model found at epoch 84 with valid_loss value: 0.20417650043964386.
# Better model found at epoch 85 with valid_loss value: 0.20348072052001953.
# Better model found at epoch 89 with valid_loss value: 0.20083965361118317.
# Better model found at epoch 92 with valid_loss value: 0.19460126757621765.
# Epoch 92: reducing lr to 0.00016211787295045837
# Better model found at epoch 96 with valid_loss value: 0.19310173392295837.
# Better model found at epoch 97 with valid_loss value: 0.19286292791366577.
# Better model found at epoch 98 with valid_loss value: 0.1907786726951599.
# Better model found at epoch 99 with valid_loss value: 0.18900993466377258.
# Better model found at epoch 101 with valid_loss value: 0.18745635449886322.
# Epoch 102: reducing lr to 0.00014446718709908415
# Better model found at epoch 105 with valid_loss value: 0.18609735369682312.
# Better model found at epoch 110 with valid_loss value: 0.1854202002286911.
# Better model found at epoch 111 with valid_loss value: 0.1851523220539093.
# Better model found at epoch 112 with valid_loss value: 0.18491017818450928.
# Epoch 112: reducing lr to 0.00012487309932431213
# Better model found at epoch 113 with valid_loss value: 0.18479816615581512.
# Better model found at epoch 115 with valid_loss value: 0.1844005584716797.
# Better model found at epoch 117 with valid_loss value: 0.1832398772239685.
# Better model found at epoch 119 with valid_loss value: 0.18240202963352203.
# Epoch 122: reducing lr to 0.00010419198997463392
# Better model found at epoch 124 with valid_loss value: 0.18153424561023712.
# Better model found at epoch 131 with valid_loss value: 0.18139685690402985.
# Better model found at epoch 132 with valid_loss value: 0.1808493584394455.
# Epoch 132: reducing lr to 8.332770504269539e-05
# Better model found at epoch 134 with valid_loss value: 0.18022601306438446.
# Better model found at epoch 139 with valid_loss value: 0.18014965951442719.
# Better model found at epoch 142 with valid_loss value: 0.17974244058132172.
# Epoch 142: reducing lr to 6.319213237554243e-05
# Better model found at epoch 144 with valid_loss value: 0.17968787252902985.
# Better model found at epoch 149 with valid_loss value: 0.17943809926509857.
# Better model found at epoch 150 with valid_loss value: 0.17938177287578583.
# Epoch 152: reducing lr to 4.466529925799532e-05
# Better model found at epoch 154 with valid_loss value: 0.17927223443984985.
# Epoch 162: reducing lr to 2.8556870993548318e-05
# Epoch 172: reducing lr to 1.557090921973359e-05
# Epoch 182: reducing lr to 6.274947115268519e-06
# Epoch 192: reducing lr to 1.0752600467690051e-06
# 0.06604715253516341 0.17926632154066832
# prodict: 100% 503/503 [00:13<00:00, 37.63it/s]
# C:\users\ffly\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
train_submission(200, 1000)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.063847</td>
#       <td>0.178578</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.062561</td>
#       <td>0.178385</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.061846</td>
#       <td>0.178323</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.061264</td>
#       <td>0.178264</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.060903</td>
#       <td>0.178248</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.060577</td>
#       <td>0.178312</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.060267</td>
#       <td>0.178311</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.060111</td>
#       <td>0.178356</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.059911</td>
#       <td>0.178453</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.059662</td>
#       <td>0.178464</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.059492</td>
#       <td>0.178586</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.059361</td>
#       <td>0.178626</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.059262</td>
#       <td>0.178683</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.059067</td>
#       <td>0.178711</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.058943</td>
#       <td>0.178702</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.058932</td>
#       <td>0.178823</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.058897</td>
#       <td>0.178986</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.058813</td>
#       <td>0.178886</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.058766</td>
#       <td>0.179001</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.058806</td>
#       <td>0.179140</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.058810</td>
#       <td>0.179247</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.058953</td>
#       <td>0.179265</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.059022</td>
#       <td>0.179388</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.059208</td>
#       <td>0.180033</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.059582</td>
#       <td>0.180486</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.059801</td>
#       <td>0.179669</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.059904</td>
#       <td>0.180033</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.060219</td>
#       <td>0.180172</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.060428</td>
#       <td>0.180017</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.061173</td>
#       <td>0.181010</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.061525</td>
#       <td>0.180446</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.061502</td>
#       <td>0.180817</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.061861</td>
#       <td>0.181342</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.062121</td>
#       <td>0.182960</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.062848</td>
#       <td>0.180456</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.063555</td>
#       <td>0.181005</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.063701</td>
#       <td>0.181710</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.064285</td>
#       <td>0.181292</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.064565</td>
#       <td>0.182357</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.064996</td>
#       <td>0.181062</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.065271</td>
#       <td>0.181871</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.065950</td>
#       <td>0.181413</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.065956</td>
#       <td>0.181936</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.065142</td>
#       <td>0.184773</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.066580</td>
#       <td>0.181902</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.066513</td>
#       <td>0.183210</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.066569</td>
#       <td>0.185633</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.066793</td>
#       <td>0.182955</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.066629</td>
#       <td>0.181643</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.066355</td>
#       <td>0.185209</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.066050</td>
#       <td>0.183591</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.066472</td>
#       <td>0.184004</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.065770</td>
#       <td>0.184197</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.065943</td>
#       <td>0.182147</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.065680</td>
#       <td>0.185505</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.065523</td>
#       <td>0.182092</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.064840</td>
#       <td>0.187491</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.065144</td>
#       <td>0.183559</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.064783</td>
#       <td>0.184940</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.064435</td>
#       <td>0.183073</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.064480</td>
#       <td>0.183834</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.064045</td>
#       <td>0.184326</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.064036</td>
#       <td>0.187777</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.063580</td>
#       <td>0.185132</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.063218</td>
#       <td>0.182529</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.063092</td>
#       <td>0.185926</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.062871</td>
#       <td>0.186412</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.063015</td>
#       <td>0.184081</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.062096</td>
#       <td>0.182533</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.062094</td>
#       <td>0.184549</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.062098</td>
#       <td>0.184299</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.061689</td>
#       <td>0.185933</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.061289</td>
#       <td>0.185009</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.061020</td>
#       <td>0.187
# Better model found at epoch 0 with valid_loss value: 0.17857827246189117.
# Better model found at epoch 1 with valid_loss value: 0.17838522791862488.
# Better model found at epoch 2 with valid_loss value: 0.1783229261636734.
# Better model found at epoch 3 with valid_loss value: 0.17826375365257263.
# Better model found at epoch 4 with valid_loss value: 0.1782480627298355.
# Epoch 10: reducing lr to 2.9967737103779228e-05
# Epoch 20: reducing lr to 8.003000730042371e-05
# Epoch 30: reducing lr to 0.00013924799608184903
# Epoch 40: reducing lr to 0.00018500244994715736
# Epoch 50: reducing lr to 0.00019997878165973243
# Epoch 60: reducing lr to 0.00019736575212051785
# Epoch 70: reducing lr to 0.0001904974131120252
# Epoch 80: reducing lr to 0.0001796739458424247
# Epoch 90: reducing lr to 0.00016536839801694806
# Epoch 100: reducing lr to 0.00014820596770888172
# Epoch 110: reducing lr to 0.00012893674737234285
# Epoch 120: reducing lr to 0.00010840292303861373
# Epoch 130: reducing lr to 8.750186718154809e-05
# Epoch 140: reducing lr to 6.714709267073658e-05
# Epoch 150: reducing lr to 4.8228191390209026e-05
# Epoch 160: reducing lr to 3.157199635622084e-05
# Epoch 170: reducing lr to 1.790650349719257e-05
# Epoch 180: reducing lr to 7.828919987831295e-06
# Epoch 190: reducing lr to 1.7796981872515628e-06
# 0.06035793090208632 0.17878398764878511
# prodict: 100% 51/51 [00:10<00:00,  5.01it/s]
# C:\users\ffly\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
