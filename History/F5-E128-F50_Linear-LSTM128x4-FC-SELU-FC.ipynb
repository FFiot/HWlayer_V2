# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5-E128-F50_Linear-LSTM128x4-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 500
evaluate_num        = 128
focus_min           = 0.5

# %%
class net_test(torch.nn.Module):
    def __init__(self, evaluate_dic_list, **kwargs):
        super(net_test, self).__init__()
        self.hw_layer = hw_layer(evaluate_dic_list)
        self.embedding = torch.nn.Linear(self.hw_layer.channels, 128, bias=False)
        self.lstm = torch.nn.LSTM(128, 128, num_layers=4, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(128*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.hw_layer(x)
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
evaluate_list = [evaluate_build(x_test[..., i], evaluate_num) for i in range(x_test.shape[-1])]
evaluate_focus_list = []
for evaluate in evaluate_list:
    focus = 1 - (len(evaluate) - 1)/10
    if focus < focus_min:
        focus = focus_min
    evaluate_focus = focus_build(evaluate, focus)
    evaluate_focus_list.append(evaluate_focus)
# Out:
# evaluate_num:   3,focus:0.8000: 3it [00:00, ?it/s]
# evaluate_num:   3,focus:0.8000: 3it [00:00, 3000.22it/s]
# evaluate_num: 127,focus:0.5000: 127it [00:00, 185.63it/s]
# evaluate_num:  99,focus:0.5000: 99it [00:00, 194.44it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]

# %%
model = net_test(evaluate_focus_list)
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (hw_layer): hw_layer(
#     (evaluate_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#     (focus_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#   )
#   (embedding): Linear(in_features=234, out_features=128, bias=False)
#   (lstm): LSTM(128, 128, num_layers=4, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=256, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 1479969 468

# %%
# state_dict = torch.load(f'models/{fname}_best.pth')
# model.load_state_dict(state_dict)

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.505281</td>
#       <td>3.224085</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.671136</td>
#       <td>1.546809</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.224550</td>
#       <td>1.175932</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.152228</td>
#       <td>1.189148</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.022833</td>
#       <td>1.008590</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.985592</td>
#       <td>0.986600</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.886212</td>
#       <td>0.908075</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.859715</td>
#       <td>0.785559</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.784199</td>
#       <td>0.757901</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.649209</td>
#       <td>0.720292</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.607782</td>
#       <td>0.605185</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.575758</td>
#       <td>0.555074</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.533908</td>
#       <td>0.552478</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.543524</td>
#       <td>0.520653</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.485769</td>
#       <td>0.462847</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.492294</td>
#       <td>0.474758</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.449074</td>
#       <td>0.442807</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.447542</td>
#       <td>0.462715</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.427340</td>
#       <td>0.419015</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.423279</td>
#       <td>0.415652</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.419217</td>
#       <td>0.387811</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.394133</td>
#       <td>0.397094</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.378646</td>
#       <td>0.377552</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.364035</td>
#       <td>0.359404</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.351445</td>
#       <td>0.356302</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.333371</td>
#       <td>0.349352</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.331584</td>
#       <td>0.326645</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.312554</td>
#       <td>0.340551</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.358545</td>
#       <td>0.418852</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.326390</td>
#       <td>0.306002</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.295687</td>
#       <td>0.293558</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.299005</td>
#       <td>0.343851</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.295290</td>
#       <td>0.286627</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.281685</td>
#       <td>0.293793</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.289142</td>
#       <td>0.305578</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.267211</td>
#       <td>0.273483</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.277066</td>
#       <td>0.274529</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.274375</td>
#       <td>0.271834</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.259839</td>
#       <td>0.258319</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.263935</td>
#       <td>0.280690</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.261071</td>
#       <td>0.366539</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.265214</td>
#       <td>0.258726</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.252063</td>
#       <td>0.261518</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.238051</td>
#       <td>0.247075</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.231964</td>
#       <td>0.249310</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.230907</td>
#       <td>0.246976</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.224273</td>
#       <td>0.240663</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.241045</td>
#       <td>0.265447</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.224832</td>
#       <td>0.237014</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.218369</td>
#       <td>0.231128</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.218914</td>
#       <td>0.227191</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.207056</td>
#       <td>0.221352</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.206497</td>
#       <td>0.227101</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.205328</td>
#       <td>0.230281</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.230153</td>
#       <td>0.270322</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.199426</td>
#       <td>0.221980</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.208330</td>
#       <td>0.221680</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.199630</td>
#       <td>0.223540</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.191532</td>
#       <td>0.213576</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.200205</td>
#       <td>0.221786</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.191751</td>
#       <td>0.221607</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.184905</td>
#       <td>0.209492</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.183115</td>
#       <td>0.204585</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.197203</td>
#       <td>0.208931</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.183484</td>
#       <td>0.212736</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.175930</td>
#       <td>0.212052</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.171787</td>
#       <td>0.199296</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0
td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.126060</td>
#       <td>0.180819</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.124975</td>
#       <td>0.178319</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.123550</td>
#       <td>0.177646</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.124043</td>
#       <td>0.177745</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.122699</td>
#       <td>0.178188</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.121760</td>
#       <td>0.177763</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.120874</td>
#       <td>0.176764</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.119777</td>
#       <td>0.176592</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.119478</td>
#       <td>0.176738</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.118836</td>
#       <td>0.176531</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.117766</td>
#       <td>0.175814</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.117394</td>
#       <td>0.176448</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.116677</td>
#       <td>0.175
# Better model found at epoch 0 with valid_loss value: 0.17885766923427582.
# Epoch 10: reducing lr to 8.591347194839051e-05
# Epoch 20: reducing lr to 0.00018807736282679062
# Epoch 30: reducing lr to 0.00019686695046697975
# Epoch 40: reducing lr to 0.0001783910593204253
# Epoch 50: reducing lr to 0.00014636080449597928
# Epoch 60: reducing lr to 0.00010631454665746575
# Better model found at epoch 62 with valid_loss value: 0.17831923067569733.
# Better model found at epoch 63 with valid_loss value: 0.17764611542224884.
# Better model found at epoch 67 with valid_loss value: 0.1767643541097641.
# Better model found at epoch 68 with valid_loss value: 0.17659179866313934.
# Better model found at epoch 70 with valid_loss value: 0.17653092741966248.
# Epoch 70: reducing lr to 6.517659400552179e-05
# Better model found at epoch 71 with valid_loss value: 0.17581361532211304.
# Better model found at epoch 75 with valid_loss value: 0.1756725162267685.
# Better model found at epoch 76 with valid_loss value: 0.17535825073719025.
# Better model found at epoch 77 with valid_loss value: 0.17520129680633545.
# Better model found at epoch 79 with valid_loss value: 0.17512159049510956.
# Better model found at epoch 80 with valid_loss value: 0.17500488460063934.
# Epoch 80: reducing lr to 3.0060106156435557e-05
# Better model found at epoch 82 with valid_loss value: 0.17483259737491608.
# Better model found at epoch 83 with valid_loss value: 0.17467857897281647.
# Better model found at epoch 85 with valid_loss value: 0.1746474951505661.
# Better model found at epoch 86 with valid_loss value: 0.17456398904323578.
# Better model found at epoch 90 with valid_loss value: 0.17450377345085144.
# Epoch 90: reducing lr to 7.037032825468617e-06
# Better model found at epoch 92 with valid_loss value: 0.17448261380195618.
# Better model found at epoch 93 with valid_loss value: 0.17446927726268768.
# Better model found at epoch 97 with valid_loss value: 0.17446380853652954.
# Better model found at epoch 99 with valid_loss value: 0.17446370422840118.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.10772749282850706 0.1739825471754997

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 101/101 [00:05<00:00, 19.92it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
# Out:
# C:\Users\ffly\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
