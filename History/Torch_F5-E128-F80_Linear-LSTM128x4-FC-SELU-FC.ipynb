# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5-E128-F80_Linear-LSTM128x4-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 500
evaluate_num        = 128
focus_min           = 0.8

# %%
class net_test(torch.nn.Module):
    def __init__(self, evaluate_dic_list, **kwargs):
        super(net_test, self).__init__()
        self.hw_layer = hw_layer(evaluate_dic_list)
        self.embedding = torch.nn.Linear(self.hw_layer.channels, 128, bias=False)
        self.lstm = torch.nn.LSTM(128, 128, num_layers=4, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(128*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.hw_layer(x)
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
evaluate_list = [evaluate_build(x_test[..., i], evaluate_num) for i in range(x_test.shape[-1])]
evaluate_focus_list = []
for evaluate in evaluate_list:
    focus = 1 - (len(evaluate) - 1)/10
    if focus < focus_min:
        focus = focus_min
    evaluate_focus = focus_build(evaluate, focus)
    evaluate_focus_list.append(evaluate_focus)
# Out:
# evaluate_num:   3,focus:0.8000: 3it [00:00, ?it/s]
# evaluate_num:   3,focus:0.8000: 3it [00:00, 3002.37it/s]
# evaluate_num: 127,focus:0.8000: 127it [00:01, 106.40it/s]
# evaluate_num:  99,focus:0.8000: 99it [00:00, 203.66it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]

# %%
model = net_test(evaluate_focus_list)
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (hw_layer): hw_layer(
#     (evaluate_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#     (focus_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#   )
#   (embedding): Linear(in_features=234, out_features=128, bias=False)
#   (lstm): LSTM(128, 128, num_layers=4, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=256, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 1479969 468

# %%
# state_dict = torch.load(f'models/{fname}_best.pth')
# model.load_state_dict(state_dict)

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.642256</td>
#       <td>3.303242</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.593252</td>
#       <td>1.474196</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.161367</td>
#       <td>1.196884</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.122406</td>
#       <td>1.064916</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.963735</td>
#       <td>0.954943</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.891350</td>
#       <td>0.966563</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.830720</td>
#       <td>0.841131</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.785151</td>
#       <td>0.766012</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.640535</td>
#       <td>0.616657</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.627527</td>
#       <td>0.629828</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.568991</td>
#       <td>0.553242</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.550297</td>
#       <td>0.583073</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.498420</td>
#       <td>0.476914</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.518818</td>
#       <td>0.496658</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.475794</td>
#       <td>0.470434</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.446645</td>
#       <td>0.457230</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.444710</td>
#       <td>0.467628</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.422441</td>
#       <td>0.419941</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.407709</td>
#       <td>0.445908</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.386379</td>
#       <td>0.377832</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.389508</td>
#       <td>0.418615</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.371315</td>
#       <td>0.374625</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.356522</td>
#       <td>0.357674</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.350787</td>
#       <td>0.346105</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.347879</td>
#       <td>0.361194</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.330475</td>
#       <td>0.339175</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.326737</td>
#       <td>0.338900</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.305423</td>
#       <td>0.330133</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.309796</td>
#       <td>0.310736</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.299069</td>
#       <td>0.300199</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.291480</td>
#       <td>0.298764</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.283823</td>
#       <td>0.290063</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.275405</td>
#       <td>0.290471</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.275232</td>
#       <td>0.281399</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.261347</td>
#       <td>0.285322</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.264460</td>
#       <td>0.278652</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.261466</td>
#       <td>0.275956</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.249904</td>
#       <td>0.263585</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.247427</td>
#       <td>0.257915</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.245574</td>
#       <td>0.257911</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.237245</td>
#       <td>0.253794</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.233886</td>
#       <td>0.247815</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.225199</td>
#       <td>0.241257</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.229691</td>
#       <td>0.245333</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.227337</td>
#       <td>0.236138</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.225328</td>
#       <td>0.253683</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.219835</td>
#       <td>0.232570</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.215169</td>
#       <td>0.233438</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.216202</td>
#       <td>0.249959</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.212718</td>
#       <td>0.232162</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.209749</td>
#       <td>0.221048</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.212950</td>
#       <td>0.230201</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.202166</td>
#       <td>0.222130</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.197967</td>
#       <td>0.222613</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.193513</td>
#       <td>0.220519</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.190532</td>
#       <td>0.216091</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.186521</td>
#       <td>0.215896</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.188836</td>
#       <td>0.210341</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.183678</td>
#       <td>0.212035</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0
td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.128928</td>
#       <td>0.188182</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.129520</td>
#       <td>0.189983</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.128820</td>
#       <td>0.187399</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.126359</td>
#       <td>0.188131</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.125102</td>
#       <td>0.187081</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.123959</td>
#       <td>0.186831</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.123929</td>
#       <td>0.188387</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.123007</td>
#       <td>0.185573</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.122504</td>
#       <td>0.189241</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.121270</td>
#       <td>0.185863</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.120951</td>
#       <td>0.186626</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.120389</td>
#       <td>0.186386</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.119592</td>
#       <td>0.185047</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.117579</td>
#       <td>0.184236</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.117892</td>
#       <td>0.185148</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.116565</td>
#       <td>0.185530</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.115990</td>
#       <td>0.184803</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.115021</td>
#       <td>0.184499</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.114503</td>
#       <td>0.184071</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.113543</td>
#       <td>0.184529</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.112722</td>
#       <td>0.184300</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.111548</td>
#       <td>0.183806</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.111914</td>
#       <td>0.183377</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.110119</td>
#       <td>0.183834</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.109669</td>
#       <td>0.183760</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.109202</td>
#       <td>0.183222</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.108500</td>
#       <td>0.183
# Better model found at epoch 0 with valid_loss value: 0.18327686190605164.
# Epoch 10: reducing lr to 8.591347194839051e-05
# Epoch 20: reducing lr to 0.00018807736282679062
# Epoch 30: reducing lr to 0.00019686695046697975
# Epoch 40: reducing lr to 0.0001783910593204253
# Epoch 50: reducing lr to 0.00014636080449597928
# Epoch 60: reducing lr to 0.00010631454665746575
# Epoch 70: reducing lr to 6.517659400552179e-05
# Better model found at epoch 72 with valid_loss value: 0.1832224428653717.
# Better model found at epoch 74 with valid_loss value: 0.18298792839050293.
# Better model found at epoch 75 with valid_loss value: 0.18289950489997864.
# Better model found at epoch 76 with valid_loss value: 0.18289873003959656.
# Better model found at epoch 78 with valid_loss value: 0.18282513320446014.
# Better model found at epoch 80 with valid_loss value: 0.18259434401988983.
# Epoch 80: reducing lr to 3.0060106156435557e-05
# Better model found at epoch 87 with valid_loss value: 0.1825551986694336.
# Better model found at epoch 89 with valid_loss value: 0.18251214921474457.
# Epoch 90: reducing lr to 7.037032825468617e-06
# Better model found at epoch 91 with valid_loss value: 0.182512104511261.
# Better model found at epoch 96 with valid_loss value: 0.18250726163387299.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.10007529761180405 0.18230772691388283

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 101/101 [00:05<00:00, 18.99it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
