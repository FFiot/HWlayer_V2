# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5_Linear-LSTM128x1-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 1000
evaluate_num        = 128
focus_min           = 0.6

# %%
class net_test(torch.nn.Module):
    def __init__(self, **kwargs):
        super(net_test, self).__init__()
        self.embedding = torch.nn.Linear(5, 128, bias=False)
        self.lstm = torch.nn.LSTM(128, 128, num_layers=1, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(128*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
model = net_test()
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (embedding): Linear(in_features=5, out_features=128, bias=False)
#   (lstm): LSTM(128, 128, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=256, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 271009 0

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.130422</td>
#       <td>2.802500</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.469191</td>
#       <td>1.414489</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.190534</td>
#       <td>1.161367</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.067172</td>
#       <td>1.059835</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.053943</td>
#       <td>0.994940</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.010816</td>
#       <td>1.015046</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.988847</td>
#       <td>1.020441</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.976288</td>
#       <td>0.917844</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0
td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.366620</td>
#       <td>0.382
# Better model found at epoch 0 with valid_loss value: 0.39424464106559753.
# Better model found at epoch 2 with valid_loss value: 0.3938050866127014.
# Epoch 10: reducing lr to 8.581716771801779e-05
# Epoch 20: reducing lr to 0.00018802998854129706
# Epoch 30: reducing lr to 0.00019687540232975727
# Epoch 40: reducing lr to 0.0001784121995859993
# Better model found at epoch 49 with valid_loss value: 0.3930436968803406.
# Epoch 50: reducing lr to 0.00014639098138880284
# Better model found at epoch 52 with valid_loss value: 0.3892216384410858.
# Epoch 60: reducing lr to 0.00010634853006612538
# Better model found at epoch 61 with valid_loss value: 0.3865564167499542.
# Better model found at epoch 66 with valid_loss value: 0.3854486048221588.
# Better model found at epoch 67 with valid_loss value: 0.3848932087421417.
# Better model found at epoch 69 with valid_loss value: 0.3841651976108551.
# Epoch 70: reducing lr to 6.520850740902317e-05
# Better model found at epoch 71 with valid_loss value: 0.3831397593021393.
# Better model found at epoch 73 with valid_loss value: 0.38215166330337524.
# Better model found at epoch 74 with valid_loss value: 0.38120734691619873.
# Better model found at epoch 75 with valid_loss value: 0.3807101547718048.
# Better model found at epoch 77 with valid_loss value: 0.3805660605430603.
# Better model found at epoch 78 with valid_loss value: 0.379949688911438.
# Better model found at epoch 79 with valid_loss value: 0.3796307444572449.
# Better model found at epoch 80 with valid_loss value: 0.3794289827346802.
# Epoch 80: reducing lr to 3.0084440781536825e-05
# Better model found at epoch 82 with valid_loss value: 0.3790152072906494.
# Better model found at epoch 83 with valid_loss value: 0.37842047214508057.
# Better model found at epoch 84 with valid_loss value: 0.37837064266204834.
# Better model found at epoch 86 with valid_loss value: 0.3774932622909546.
# Better model found at epoch 89 with valid_loss value: 0.3771619200706482.
# Better model found at epoch 90 with valid_loss value: 0.3770170211791992.
# Epoch 90: reducing lr to 7.049580994910807e-06
# Better model found at epoch 92 with valid_loss value: 0.3769737482070923.
# Better model found at epoch 93 with valid_loss value: 0.3768979609012604.
# Better model found at epoch 94 with valid_loss value: 0.3766785264015198.
# Better model found at epoch 96 with valid_loss value: 0.37662258744239807.
# Better model found at epoch 97 with valid_loss value: 0.37656041979789734.
# Better model found at epoch 98 with valid_loss value: 0.37655770778656006.
# Better model found at epoch 99 with valid_loss value: 0.3765515983104706.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.35731826551624984 0.3762109559029341

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 51/51 [00:01<00:00, 38.92it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
