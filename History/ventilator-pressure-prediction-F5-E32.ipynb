# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 1000
evaluate_num        = 32
focus_min           = 0.8

# %%
class net_test(torch.nn.Module):
    def __init__(self, evaluate_dic_list, **kwargs):
        super(net_test, self).__init__()
        self.hw_layer = hw_layer(evaluate_dic_list)
        self.hw_dims = self.hw_layer.channels
        self.lstm = torch.nn.LSTM(self.hw_dims, self.hw_dims, num_layers=4, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(self.hw_dims*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        hw = self.hw_layer(x)
        x, _ = self.lstm(hw)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
evaluate_list = [evaluate_build(x_test[..., i], evaluate_num) for i in range(x_test.shape[-1])]
evaluate_focus_list = []
for evaluate in evaluate_list:
    focus = 1 - (len(evaluate) - 1)/10
    if focus < focus_min:
        focus = focus_min
    evaluate_focus = focus_build(evaluate, focus)
    evaluate_focus_list.append(evaluate_focus)
# Out:
# evaluate_num:   3,focus:0.8000: 3it [00:00, ?it/s]
# evaluate_num:   3,focus:0.8000: 3it [00:00, ?it/s]
# evaluate_num:  32,focus:0.8000: 32it [00:00, 1604.40it/s]
# evaluate_num:  25,focus:0.8000: 25it [00:00, 1566.54it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]

# %%
model = net_test(evaluate_focus_list)
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (hw_layer): hw_layer(
#     (evaluate_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(32, 1)
#       (3): Embedding(25, 1)
#       (4): Embedding(2, 1)
#     )
#     (focus_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(32, 1)
#       (3): Embedding(25, 1)
#       (4): Embedding(2, 1)
#     )
#   )
#   (lstm): LSTM(65, 65, num_layers=4, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=130, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 375993 130

# %%
# state_dict = torch.load(f'models/{fname}_best.pth')
# model.load_state_dict(state_dict)

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.356281</td>
#       <td>3.945675</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.654808</td>
#       <td>1.566442</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.239759</td>
#       <td>1.199641</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.164068</td>
#       <td>1.282470</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.094841</td>
#       <td>1.105518</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.075994</td>
#       <td>1.050919</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.981975</td>
#       <td>0.956031</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.990707</td>
#       <td>0.988162</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.904591</td>
#       <td>0.903271</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.868833</td>
#       <td>0.955492</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.827256</td>
#       <td>0.821944</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.808098</td>
#       <td>0.788663</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.702000</td>
#       <td>0.714966</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.611126</td>
#       <td>0.627746</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.598525</td>
#       <td>0.595939</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.576982</td>
#       <td>0.554930</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.601097</td>
#       <td>0.572368</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.529930</td>
#       <td>0.581528</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.505670</td>
#       <td>0.498228</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.495012</td>
#       <td>0.474854</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.487521</td>
#       <td>0.498066</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.470923</td>
#       <td>0.451425</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.448257</td>
#       <td>0.450815</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.463878</td>
#       <td>0.544477</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.424604</td>
#       <td>0.416802</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.419785</td>
#       <td>0.419887</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.412478</td>
#       <td>0.408543</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.406106</td>
#       <td>0.402124</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.394311</td>
#       <td>0.414294</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.381882</td>
#       <td>0.387600</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.372804</td>
#       <td>0.400485</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.374090</td>
#       <td>0.371376</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.371313</td>
#       <td>0.386019</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.354902</td>
#       <td>0.355623</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.359502</td>
#       <td>0.349347</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.354290</td>
#       <td>0.360585</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.340374</td>
#       <td>0.357575</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.340544</td>
#       <td>0.340662</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.335421</td>
#       <td>0.338588</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.331483</td>
#       <td>0.345532</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.321763</td>
#       <td>0.339474</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.319733</td>
#       <td>0.329338</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.311414</td>
#       <td>0.323532</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.317005</td>
#       <td>0.363553</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.305748</td>
#       <td>0.324749</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.314108</td>
#       <td>0.314061</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.301880</td>
#       <td>0.307470</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.294301</td>
#       <td>0.303210</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.291356</td>
#       <td>0.308358</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.292637</td>
#       <td>0.301940</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.290717</td>
#       <td>0.307915</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.298101</td>
#       <td>0.306278</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.288899</td>
#       <td>0.301371</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.284226</td>
#       <td>0.293010</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.275703</td>
#       <td>0.290118</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.275029</td>
#       <td>0.293856</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.268829</td>
#       <td>0.285411</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.272283</td>
#       <td>0.308885</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.272585</td>
#       <td>0.288938</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.263591</td>
#       <td>0.281681</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.261100</td>
#       <td>0.280253</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.262672</td>
#       <td>0.277365</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.253015</td>
#       <td>0.271263</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.248670</td>
#       <td>0.266581</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.256462</td>
#       <td>0.274417</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.246315</td>
#       <td>0.267950</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.240976</td>
#       <td>0.266015</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.247523</td>
#       <td>0.265247</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.239312</td>
#       <td>0.263125</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.240247</td>
#       <td>0.259709</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.232949</td>
#       <td>0.258069</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0
td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.189430</td>
#       <td>0.239307</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.189607</td>
#       <td>0.231687</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.188782</td>
#       <td>0.232875</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.187220</td>
#       <td>0.231741</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.186430</td>
#       <td>0.238289</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.188744</td>
#       <td>0.231
# Better model found at epoch 0 with valid_loss value: 0.23796430230140686.
# Better model found at epoch 1 with valid_loss value: 0.23779068887233734.
# Epoch 10: reducing lr to 8.581716771801779e-05
# Epoch 20: reducing lr to 0.00018802998854129706
# Epoch 30: reducing lr to 0.00019687540232975727
# Epoch 40: reducing lr to 0.0001784121995859993
# Better model found at epoch 47 with valid_loss value: 0.23766063153743744.
# Better model found at epoch 50 with valid_loss value: 0.23705239593982697.
# Epoch 50: reducing lr to 0.00014639098138880284
# Better model found at epoch 53 with valid_loss value: 0.2366800606250763.
# Better model found at epoch 56 with valid_loss value: 0.23515650629997253.
# Better model found at epoch 58 with valid_loss value: 0.23416012525558472.
# Epoch 60: reducing lr to 0.00010634853006612538
# Better model found at epoch 61 with valid_loss value: 0.23337768018245697.
# Better model found at epoch 64 with valid_loss value: 0.23156720399856567.
# Epoch 70: reducing lr to 6.520850740902317e-05
# Better model found at epoch 74 with valid_loss value: 0.2304994761943817.
# Better model found at epoch 75 with valid_loss value: 0.2301798164844513.
# Better model found at epoch 76 with valid_loss value: 0.22940142452716827.
# Better model found at epoch 77 with valid_loss value: 0.22939640283584595.
# Better model found at epoch 78 with valid_loss value: 0.22923371195793152.
# Better model found at epoch 79 with valid_loss value: 0.22871717810630798.
# Epoch 80: reducing lr to 3.0084440781536825e-05
# Better model found at epoch 81 with valid_loss value: 0.22855371236801147.
# Better model found at epoch 83 with valid_loss value: 0.22848258912563324.
# Better model found at epoch 84 with valid_loss value: 0.228383868932724.
# Better model found at epoch 85 with valid_loss value: 0.2283111810684204.
# Better model found at epoch 86 with valid_loss value: 0.22802826762199402.
# Better model found at epoch 87 with valid_loss value: 0.2278173267841339.
# Epoch 90: reducing lr to 7.049580994910807e-06
# Better model found at epoch 91 with valid_loss value: 0.22774018347263336.
# Better model found at epoch 93 with valid_loss value: 0.22761574387550354.
# Better model found at epoch 94 with valid_loss value: 0.22752338647842407.
# Better model found at epoch 97 with valid_loss value: 0.22751431167125702.
# Better model found at epoch 98 with valid_loss value: 0.22750090062618256.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.17858857869124803 0.22619003057479858

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 51/51 [00:04<00:00, 11.73it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
# Out:
# C:\users\ffly\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
