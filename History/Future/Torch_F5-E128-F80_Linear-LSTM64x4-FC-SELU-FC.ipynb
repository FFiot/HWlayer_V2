# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5-E128-F80_Linear-LSTM64x4-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 1000
evaluate_num        = 128
focus_min           = 0.8

# %%
class net_test(torch.nn.Module):
    def __init__(self, evaluate_dic_list, **kwargs):
        super(net_test, self).__init__()
        self.hw_layer = hw_layer(evaluate_dic_list)
        self.embedding = torch.nn.Linear(self.hw_layer.channels, 64, bias=False)
        self.lstm = torch.nn.LSTM(64, 64, num_layers=4, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(64*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.hw_layer(x)
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
evaluate_list = [evaluate_build(x_test[..., i], evaluate_num) for i in range(x_test.shape[-1])]
evaluate_focus_list = []
for evaluate in evaluate_list:
    focus = 1 - (len(evaluate) - 1)/10
    if focus < focus_min:
        focus = focus_min
    evaluate_focus = focus_build(evaluate, focus)
    evaluate_focus_list.append(evaluate_focus)
# Out:
# evaluate_num:   3,focus:0.8000: 3it [00:00, ?it/s]
# evaluate_num:   3,focus:0.8000: 3it [00:00, 3000.93it/s]
# evaluate_num: 127,focus:0.8000: 127it [00:01, 95.64it/s]
# evaluate_num:  99,focus:0.8000: 99it [00:00, 175.49it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]

# %%
model = net_test(evaluate_focus_list)
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (hw_layer): hw_layer(
#     (evaluate_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#     (focus_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#   )
#   (embedding): Linear(in_features=234, out_features=64, bias=False)
#   (lstm): LSTM(64, 64, num_layers=4, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=128, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 379553 468

# %%
# state_dict = torch.load(f'models/{fname}_best.pth')
# model.load_state_dict(state_dict)

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.700837</td>
#       <td>4.408575</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.981113</td>
#       <td>2.982096</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.394318</td>
#       <td>1.364165</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.208186</td>
#       <td>1.292518</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.080188</td>
#       <td>1.082327</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.024531</td>
#       <td>1.048515</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.931426</td>
#       <td>0.897308</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.887708</td>
#       <td>0.869940</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.833809</td>
#       <td>0.816240</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.805610</td>
#       <td>0.775461</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.706369</td>
#       <td>0.679897</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.621110</td>
#       <td>0.585801</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.599027</td>
#       <td>0.590918</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.560651</td>
#       <td>0.545680</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.540487</td>
#       <td>0.649421</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.519910</td>
#       <td>0.513214</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.487918</td>
#       <td>0.540583</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.506537</td>
#       <td>0.597935</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.503390</td>
#       <td>0.475507</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.472000</td>
#       <td>0.444199</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.447654</td>
#       <td>0.547722</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.433173</td>
#       <td>0.436806</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.414723</td>
#       <td>0.434090</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.411913</td>
#       <td>0.408173</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.396602</td>
#       <td>0.397383</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.385121</td>
#       <td>0.375985</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.387145</td>
#       <td>0.396808</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.375325</td>
#       <td>0.388756</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.364252</td>
#       <td>0.356403</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.351867</td>
#       <td>0.358587</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.349177</td>
#       <td>0.339878</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.340442</td>
#       <td>0.341376</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.338992</td>
#       <td>0.384922</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.322412</td>
#       <td>0.345120</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.324933</td>
#       <td>0.334279</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.330122</td>
#       <td>0.362349</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.312153</td>
#       <td>0.323356</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.304511</td>
#       <td>0.314180</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.300990</td>
#       <td>0.307076</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.291684</td>
#       <td>0.293044</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.294104</td>
#       <td>0.311708</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.289344</td>
#       <td>0.292748</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.283490</td>
#       <td>0.295619</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.283600</td>
#       <td>0.300877</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.274071</td>
#       <td>0.293516</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.267852</td>
#       <td>0.274718</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.265514</td>
#       <td>0.278896</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.266885</td>
#       <td>0.278296</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.258779</td>
#       <td>0.285945</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.273028</td>
#       <td>0.279412</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.256010</td>
#       <td>0.269916</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.251578</td>
#       <td>0.261375</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.253816</td>
#       <td>0.266978</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.241626</td>
#       <td>0.260298</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.243787</td>
#       <td>0.259747</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.237910</td>
#       <td>0.255958</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.238113</td>
#       <td>0.254239</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.245817</td>
#       <td>0.257728</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.232987</td>
#       <td>0.249114</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.237494</td>
#       <td>0.257180</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.226987</td>
#       <td>0.242968</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.224274</td>
#       <td>0.241385</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.223159</td>
#       <td>0.247475</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.225181</td>
#       <td>0.242627</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.215356</td>
#       <td>0.236792</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.214229</td>
#       <td>0.237326</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.209429</td>
#       <td>0.233294</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.207359</td>
#       <td>0.237986</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.209010</td>
#       <td>0.240753</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.206086</td>
#       <td>0.226877</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.201327</td>
#       <td>0.228012</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0
td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.160185</td>
#       <td>0.204575</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.166734</td>
#       <td>0.222285</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.164077</td>
#       <td>0.205735</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.160378</td>
#       <td>0.204522</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.158965</td>
#       <td>0.204653</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.158091</td>
#       <td>0.204167</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.157595</td>
#       <td>0.204
# Better model found at epoch 0 with valid_loss value: 0.20968300104141235.
# Epoch 10: reducing lr to 8.581716771801779e-05
# Epoch 20: reducing lr to 0.00018802998854129706
# Epoch 30: reducing lr to 0.00019687540232975727
# Epoch 40: reducing lr to 0.0001784121995859993
# Better model found at epoch 48 with valid_loss value: 0.20949624478816986.
# Epoch 50: reducing lr to 0.00014639098138880284
# Better model found at epoch 51 with valid_loss value: 0.2077692151069641.
# Better model found at epoch 56 with valid_loss value: 0.20748884975910187.
# Better model found at epoch 57 with valid_loss value: 0.20736326277256012.
# Better model found at epoch 59 with valid_loss value: 0.20733891427516937.
# Epoch 60: reducing lr to 0.00010634853006612538
# Better model found at epoch 62 with valid_loss value: 0.2056654542684555.
# Better model found at epoch 65 with valid_loss value: 0.20535042881965637.
# Better model found at epoch 66 with valid_loss value: 0.20491890609264374.
# Better model found at epoch 67 with valid_loss value: 0.20457513630390167.
# Better model found at epoch 70 with valid_loss value: 0.20452231168746948.
# Epoch 70: reducing lr to 6.520850740902317e-05
# Better model found at epoch 72 with valid_loss value: 0.2041669636964798.
# Better model found at epoch 73 with valid_loss value: 0.20411692559719086.
# Better model found at epoch 74 with valid_loss value: 0.20386309921741486.
# Better model found at epoch 75 with valid_loss value: 0.20350868999958038.
# Better model found at epoch 76 with valid_loss value: 0.20342180132865906.
# Better model found at epoch 78 with valid_loss value: 0.20311743021011353.
# Better model found at epoch 79 with valid_loss value: 0.2029532790184021.
# Epoch 80: reducing lr to 3.0084440781536825e-05
# Better model found at epoch 82 with valid_loss value: 0.202520489692688.
# Better model found at epoch 85 with valid_loss value: 0.2022732049226761.
# Better model found at epoch 87 with valid_loss value: 0.20217977464199066.
# Epoch 90: reducing lr to 7.049580994910807e-06
# Better model found at epoch 92 with valid_loss value: 0.202021062374115.
# Better model found at epoch 95 with valid_loss value: 0.20201875269412994.
# Better model found at epoch 97 with valid_loss value: 0.20201459527015686.
# Better model found at epoch 98 with valid_loss value: 0.20201405882835388.
# Better model found at epoch 99 with valid_loss value: 0.20201291143894196.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.15153611585742138 0.20088773593306541

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 51/51 [00:02<00:00, 24.30it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
