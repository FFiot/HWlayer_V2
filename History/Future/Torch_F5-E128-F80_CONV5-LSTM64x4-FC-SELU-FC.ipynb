# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5-E128-F80_CONV5-LSTM64x4-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 1000
evaluate_num        = 128
focus_min           = 0.8

# %%
class net_test(torch.nn.Module):
    def __init__(self, evaluate_dic_list, **kwargs):
        super(net_test, self).__init__()
        self.hw_layer = hw_layer(evaluate_dic_list)
        self.embedding = torch.nn.Conv1d(self.hw_layer.channels, 64, 5, 1, 2, bias=False)
        self.lstm = torch.nn.LSTM(64, 64, num_layers=4, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(64*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.hw_layer(x)
        x = torch.transpose(x, -1, -2)
        x = self.embedding(x)
        x = torch.transpose(x, -1, -2)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
evaluate_list = [evaluate_build(x_test[..., i], evaluate_num) for i in range(x_test.shape[-1])]
evaluate_focus_list = []
for evaluate in evaluate_list:
    focus = 1 - (len(evaluate) - 1)/10
    if focus < focus_min:
        focus = focus_min
    evaluate_focus = focus_build(evaluate, focus)
    evaluate_focus_list.append(evaluate_focus)
# Out:
# evaluate_num:   3,focus:0.8000: 3it [00:00, 3000.93it/s]
# evaluate_num:   3,focus:0.8000: 3it [00:00, 2998.07it/s]
# evaluate_num: 127,focus:0.8000: 127it [00:01, 98.68it/s]
# evaluate_num:  99,focus:0.8000: 99it [00:00, 177.90it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, 2000.62it/s]

# %%
model = net_test(evaluate_focus_list)
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (hw_layer): hw_layer(
#     (evaluate_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#     (focus_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#   )
#   (embedding): Conv1d(234, 64, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#   (lstm): LSTM(64, 64, num_layers=4, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=128, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 439457 468

# %%
# state_dict = torch.load(f'models/{fname}_best.pth')
# model.load_state_dict(state_dict)

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.782207</td>
#       <td>4.436661</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.923345</td>
#       <td>1.769738</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.148186</td>
#       <td>1.148237</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.065740</td>
#       <td>1.030287</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.934962</td>
#       <td>0.924462</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.937670</td>
#       <td>0.960123</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.845142</td>
#       <td>0.825700</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.833789</td>
#       <td>0.802061</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.778428</td>
#       <td>0.802440</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.729614</td>
#       <td>0.688047</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.615346</td>
#       <td>0.678236</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.574187</td>
#       <td>0.555231</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.559294</td>
#       <td>0.587832</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.550120</td>
#       <td>0.526668</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.508238</td>
#       <td>0.491894</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.482625</td>
#       <td>0.472721</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.466001</td>
#       <td>0.467796</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.443378</td>
#       <td>0.508781</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.440753</td>
#       <td>0.423068</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.421650</td>
#       <td>0.417083</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.409324</td>
#       <td>0.405073</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.410194</td>
#       <td>0.472806</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.426852</td>
#       <td>0.426115</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.376347</td>
#       <td>0.380597</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.388211</td>
#       <td>0.445314</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.368003</td>
#       <td>0.415631</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.358221</td>
#       <td>0.361272</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.355435</td>
#       <td>0.357414</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.336985</td>
#       <td>0.363116</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.334695</td>
#       <td>0.328466</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.317423</td>
#       <td>0.330451</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.323027</td>
#       <td>0.318723</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.342925</td>
#       <td>0.348706</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.302175</td>
#       <td>0.309362</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.296613</td>
#       <td>0.302785</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.305004</td>
#       <td>0.323531</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.288109</td>
#       <td>0.298678</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.286912</td>
#       <td>0.302818</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.283552</td>
#       <td>0.287648</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.273749</td>
#       <td>0.290168</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.285203</td>
#       <td>0.305798</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.265719</td>
#       <td>0.276893</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.266181</td>
#       <td>0.285622</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.287958</td>
#       <td>0.287262</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.256557</td>
#       <td>0.270482</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.252582</td>
#       <td>0.273575</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.254392</td>
#       <td>0.283000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.245937</td>
#       <td>0.263564</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.248613</td>
#       <td>0.268196</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.237946</td>
#       <td>0.263641</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.245239</td>
#       <td>0.261542</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.241575</td>
#       <td>0.262132</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.229583</td>
#       <td>0.259443</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.233233</td>
#       <td>0.260970</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.228699</td>
#       <td>0.261253</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.225720</td>
#       <td>0.251886</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.230736</td>
#       <td>0.259852</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.221867</td>
#       <td>0.254120</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.214391</td>
#       <td>0.243677</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.216008</td>
#       <td>0.244204</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.211822</td>
#       <td>0.238013</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.207963</td>
#       <td>0.237420</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.205689</td>
#       <td>0.234316</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.203493</td>
#       <td>0.233470</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.203329</td>
#       <td>0.234148</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.198558</td>
#       <td>0.230894</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0
td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.151028</td>
#       <td>0.207686</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.150879</td>
#       <td>0.207721</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.150847</td>
#       <td>0.207790</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.149999</td>
#       <td>0.207778</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.149655</td>
#       <td>0.206779</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.148695</td>
#       <td>0.207077</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.148371</td>
#       <td>0.207136</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.148292</td>
#       <td>0.206644</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.147550</td>
#       <td>0.206501</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.147256</td>
#       <td>0.206358</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.146854</td>
#       <td>0.206248</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.146344</td>
#       <td>0.205
# Better model found at epoch 0 with valid_loss value: 0.20950451493263245.
# Epoch 10: reducing lr to 8.581716771801779e-05
# Epoch 20: reducing lr to 0.00018802998854129706
# Epoch 30: reducing lr to 0.00019687540232975727
# Epoch 40: reducing lr to 0.0001784121995859993
# Epoch 50: reducing lr to 0.00014639098138880284
# Better model found at epoch 53 with valid_loss value: 0.20927263796329498.
# Better model found at epoch 55 with valid_loss value: 0.20866325497627258.
# Better model found at epoch 59 with valid_loss value: 0.20842689275741577.
# Better model found at epoch 60 with valid_loss value: 0.20759165287017822.
# Epoch 60: reducing lr to 0.00010634853006612538
# Better model found at epoch 66 with valid_loss value: 0.2067791372537613.
# Better model found at epoch 69 with valid_loss value: 0.206643745303154.
# Better model found at epoch 70 with valid_loss value: 0.20650054514408112.
# Epoch 70: reducing lr to 6.520850740902317e-05
# Better model found at epoch 71 with valid_loss value: 0.20635804533958435.
# Better model found at epoch 72 with valid_loss value: 0.20624807476997375.
# Better model found at epoch 73 with valid_loss value: 0.20594128966331482.
# Better model found at epoch 75 with valid_loss value: 0.20587845146656036.
# Better model found at epoch 76 with valid_loss value: 0.20567508041858673.
# Better model found at epoch 77 with valid_loss value: 0.20551994442939758.
# Better model found at epoch 78 with valid_loss value: 0.20532628893852234.
# Better model found at epoch 79 with valid_loss value: 0.20522865653038025.
# Epoch 80: reducing lr to 3.0084440781536825e-05
# Better model found at epoch 82 with valid_loss value: 0.20519159734249115.
# Better model found at epoch 83 with valid_loss value: 0.20498692989349365.
# Better model found at epoch 85 with valid_loss value: 0.20486412942409515.
# Better model found at epoch 86 with valid_loss value: 0.20483431220054626.
# Better model found at epoch 89 with valid_loss value: 0.20469465851783752.
# Epoch 90: reducing lr to 7.049580994910807e-06
# Better model found at epoch 94 with valid_loss value: 0.20466060936450958.
# Better model found at epoch 97 with valid_loss value: 0.20465631783008575.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.14093518794560042 0.20456573367118835

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 51/51 [00:02<00:00, 19.86it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
