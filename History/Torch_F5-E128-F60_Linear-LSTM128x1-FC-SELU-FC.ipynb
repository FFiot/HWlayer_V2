# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5-E128-F60_Linear-LSTM128x1-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 100
batch_size_second   = 1000
evaluate_num        = 128
focus_min           = 0.6

# %%
class net_test(torch.nn.Module):
    def __init__(self, evaluate_dic_list, **kwargs):
        super(net_test, self).__init__()
        self.hw_layer = hw_layer(evaluate_dic_list)
        self.embedding = torch.nn.Linear(self.hw_layer.channels, 128, bias=False)
        self.lstm = torch.nn.LSTM(128, 128, num_layers=1, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(128*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.hw_layer(x)
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
evaluate_list = [evaluate_build(x_test[..., i], evaluate_num) for i in range(x_test.shape[-1])]
evaluate_focus_list = []
for evaluate in evaluate_list:
    focus = 1 - (len(evaluate) - 1)/10
    if focus < focus_min:
        focus = focus_min
    evaluate_focus = focus_build(evaluate, focus)
    evaluate_focus_list.append(evaluate_focus)
# Out:
# evaluate_num:   3,focus:0.8000: 3it [00:00, 3000.93it/s]
# evaluate_num:   3,focus:0.8000: 3it [00:00, ?it/s]
# evaluate_num: 127,focus:0.6000: 127it [00:00, 183.22it/s]
# evaluate_num:  99,focus:0.6000: 99it [00:00, 147.95it/s]
# evaluate_num:   2,focus:0.9000: 2it [00:00, ?it/s]

# %%
model = net_test(evaluate_focus_list)
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (hw_layer): hw_layer(
#     (evaluate_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#     (focus_list): ModuleList(
#       (0): Embedding(3, 1)
#       (1): Embedding(3, 1)
#       (2): Embedding(127, 1)
#       (3): Embedding(99, 1)
#       (4): Embedding(2, 1)
#     )
#   )
#   (embedding): Linear(in_features=234, out_features=128, bias=False)
#   (lstm): LSTM(128, 128, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=256, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 300321 468

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.265047</td>
#       <td>3.065380</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.734800</td>
#       <td>1.695160</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.270432</td>
#       <td>1.228646</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.124450</td>
#       <td>1.095072</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.017735</td>
#       <td>1.045134</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.925295</td>
#       <td>0.914149</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.804388</td>
#       <td>0.761073</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.734205</td>
#       <td>0.774569</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.684093</td>
#       <td>0.677189</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.652817</td>
#       <td>0.714124</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.623639</td>
#       <td>0.660236</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.608761</td>
#       <td>0.672779</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.584767</td>
#       <td>0.546458</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.568403</td>
#       <td>0.637150</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.605459</td>
#       <td>0.555608</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.529791</td>
#       <td>0.511744</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.505714</td>
#       <td>0.576563</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.502832</td>
#       <td>0.473516</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.481002</td>
#       <td>0.495791</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.466110</td>
#       <td>0.471287</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.458145</td>
#       <td>0.455058</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.458847</td>
#       <td>0.455811</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.436681</td>
#       <td>0.424947</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.433255</td>
#       <td>0.423486</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.424457</td>
#       <td>0.432009</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.414919</td>
#       <td>0.418456</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.402233</td>
#       <td>0.404234</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.391705</td>
#       <td>0.398615</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.395319</td>
#       <td>0.399854</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.386757</td>
#       <td>0.404664</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.380095</td>
#       <td>0.387127</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.372380</td>
#       <td>0.394377</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.366080</td>
#       <td>0.399760</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.370497</td>
#       <td>0.372861</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.359939</td>
#       <td>0.369998</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.358291</td>
#       <td>0.357017</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.357445</td>
#       <td>0.363567</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.347752</td>
#       <td>0.360059</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.347584</td>
#       <td>0.360210</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.346721</td>
#       <td>0.364739</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.342580</td>
#       <td>0.349814</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.332662</td>
#       <td>0.356486</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.331266</td>
#       <td>0.338023</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.329937</td>
#       <td>0.339506</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.323230</td>
#       <td>0.340688</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.324006</td>
#       <td>0.340207</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.317789</td>
#       <td>0.330313</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.315045</td>
#       <td>0.334278</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.313967</td>
#       <td>0.329321</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.311228</td>
#       <td>0.330948</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.306831</td>
#       <td>0.328334</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.304955</td>
#       <td>0.333167</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.299561</td>
#       <td>0.327635</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.303829</td>
#       <td>0.332527</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.296731</td>
#       <td>0.317270</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.298716</td>
#       <td>0.320128</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.295613</td>
#       <td>0.321797</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.287596</td>
#       <td>0.316655</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.289939</td>
#       <td>0.311023</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.289058</td>
#       <td>0.310686</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.285269</td>
#       <td>0.307212</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.279894</td>
#       <td>0.313571</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.277779</td>
#       <td>0.305080</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.277240</td>
#       <td>0.302496</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.274897</td>
#       <td>0.303530</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.277166</td>
#       <td>0.303546</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.271328</td>
#       <td>0.300706</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.268439</td>
#       <td>0.302003</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.268774</td>
#       <td>0.297515</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.266836</td>
#       <td>0.299442</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.265368</td>
#       <td>0.302405</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.264756</td>
#       <td>0.295197</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.262144</td>
#       <td>0.296377</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0
td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.224606</td>
#       <td>0.278324</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.224264</td>
#       <td>0.278234</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.223356</td>
#       <td>0.278
# Better model found at epoch 0 with valid_loss value: 0.282597154378891.
# Better model found at epoch 1 with valid_loss value: 0.28244566917419434.
# Epoch 10: reducing lr to 8.581716771801779e-05
# Epoch 20: reducing lr to 0.00018802998854129706
# Epoch 30: reducing lr to 0.00019687540232975727
# Epoch 40: reducing lr to 0.0001784121995859993
# Better model found at epoch 49 with valid_loss value: 0.2813155949115753.
# Epoch 50: reducing lr to 0.00014639098138880284
# Better model found at epoch 55 with valid_loss value: 0.28079479932785034.
# Better model found at epoch 58 with valid_loss value: 0.2803008258342743.
# Epoch 60: reducing lr to 0.00010634853006612538
# Better model found at epoch 61 with valid_loss value: 0.28024566173553467.
# Better model found at epoch 62 with valid_loss value: 0.2795713245868683.
# Better model found at epoch 66 with valid_loss value: 0.27872660756111145.
# Epoch 70: reducing lr to 6.520850740902317e-05
# Better model found at epoch 71 with valid_loss value: 0.2783244550228119.
# Better model found at epoch 72 with valid_loss value: 0.2782337963581085.
# Better model found at epoch 75 with valid_loss value: 0.2780715823173523.
# Better model found at epoch 77 with valid_loss value: 0.27771875262260437.
# Better model found at epoch 78 with valid_loss value: 0.2777094841003418.
# Better model found at epoch 79 with valid_loss value: 0.27749213576316833.
# Epoch 80: reducing lr to 3.0084440781536825e-05
# Better model found at epoch 81 with valid_loss value: 0.27739667892456055.
# Better model found at epoch 82 with valid_loss value: 0.27693960070610046.
# Better model found at epoch 83 with valid_loss value: 0.27681100368499756.
# Better model found at epoch 84 with valid_loss value: 0.2766660153865814.
# Better model found at epoch 88 with valid_loss value: 0.2765391170978546.
# Better model found at epoch 90 with valid_loss value: 0.2764629125595093.
# Epoch 90: reducing lr to 7.049580994910807e-06
# Better model found at epoch 91 with valid_loss value: 0.2764604091644287.
# Better model found at epoch 92 with valid_loss value: 0.27641305327415466.
# Better model found at epoch 93 with valid_loss value: 0.2763809263706207.
# Better model found at epoch 96 with valid_loss value: 0.27637723088264465.
# Better model found at epoch 97 with valid_loss value: 0.276347279548645.

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.21783374543072748 0.2766102943569422

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 51/51 [00:01<00:00, 29.11it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8792/3362214087.py in <module>
# ----> 1 df = pd.read_csv('Database/sample_submission.csv', index_col=0)
#       2 df['pressure'] = predict
#       3
#       4 df.to_csv(f'Submission/{fname}.csv')
#
# NameError: name 'pd' is not defined
