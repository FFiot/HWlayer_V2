# %% [markdown]
# Reference
# * https://www.kaggle.com/hirayukis/pytorch-lstm-cv-0-1942-lb-0-193
#   * 242,5729
# * https://www.kaggle.com/dienhoa/ventillator-fastai-lb-0-168-no-kfolds-no-blend?scriptVersionId=78176083
#   * 1051,2501

# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchsummary import summary

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_base import evaluate_build, focus_build
from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_torch import torch_valid, torch_predict

# %%
fname = 'F25_RobustScaler_LSTM(500-400-300-200)_(FC-SELU-FC)'
epoch_num = 350
batch_size = 512

# %%
class RNNModel(nn.Module):
    def __init__(self, input_size=25):
        hidden = [500, 400, 300, 200]
        super().__init__()
        self.lstm1 = nn.LSTM(input_size, hidden[0],
                             batch_first=True, bidirectional=True)
        self.lstm2 = nn.LSTM(2 * hidden[0], hidden[1],
                             batch_first=True, bidirectional=True)
        self.lstm3 = nn.LSTM(2 * hidden[1], hidden[2],
                             batch_first=True, bidirectional=True)
        self.lstm4 = nn.LSTM(2 * hidden[2], hidden[3],
                             batch_first=True, bidirectional=True)
        self.fc1 = nn.Linear(2 * hidden[3], 50)
        self.selu = nn.SELU()
        self.fc2 = nn.Linear(50, 1)
        self._reinitialize()

    def _reinitialize(self):
        """
        Tensorflow/Keras-like initialization
        """
        for name, p in self.named_parameters():
            if 'lstm' in name:
                if 'weight_ih' in name:
                    nn.init.xavier_uniform_(p.data)
                elif 'weight_hh' in name:
                    nn.init.orthogonal_(p.data)
                elif 'bias_ih' in name:
                    p.data.fill_(0)
                    # Set forget-gate bias to 1
                    n = p.size(0)
                    p.data[(n // 4):(n // 2)].fill_(1)
                elif 'bias_hh' in name:
                    p.data.fill_(0)
            elif 'fc' in name:
                if 'weight' in name:
                    nn.init.xavier_uniform_(p.data)
                elif 'bias' in name:
                    p.data.fill_(0)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x, _ = self.lstm3(x)
        x, _ = self.lstm4(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)

        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
def add_features(df):
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['cross']= df['u_in']*df['u_out']
    df['cross2']= df['time_step']*df['u_out']
    
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['u_in_lag'] = df['u_in_lag']*df['breath_id_lagsame']
    df['u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['u_in_lag2'] = df['u_in_lag2']*df['breath_id_lag2same']
    df['u_out_lag2'] = df['u_out'].shift(2).fillna(0)
    df['u_out_lag2'] = df['u_out_lag2']*df['breath_id_lag2same']
    #df['u_in_lag'] = df['u_in'].shift(2).fillna(0)
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['RC'] = df['R']+df['C']
    df = pd.get_dummies(df)
    return df

# %%
data_train_df = add_features(data_train_df)
data_test_df = add_features(data_test_df)

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
RS = RobustScaler()
data_train = data_train_df[x_columns].values
data_train = RS.fit_transform(data_train).astype(np.float32)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values
data_test = RS.transform(data_test).astype(np.float32)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
print(data_train.shape)
# Out:
# (75450, 80, 25)

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

print(len(train_index), len(valid_index))

x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test
# Out:
# 60360 15090

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 22

# %%
model = RNNModel()
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# RNNModel(
#   (lstm1): LSTM(25, 500, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(1000, 400, batch_first=True, bidirectional=True)
#   (lstm3): LSTM(800, 300, batch_first=True, bidirectional=True)
#   (lstm4): LSTM(600, 200, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=400, out_features=50, bias=True)
#   (selu): SELU()
#   (fc2): Linear(in_features=50, out_features=1, bias=True)
# )
# 10542501 0

# %%
def train_submission(epoch_num, batch_size):
    dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size)
    learn = Learner(dataLoads, model, loss_func=L1LossFlat())
    learn.lr_find()
    learn.fit_one_cycle(epoch_num, lr_max=2e-3, cbs=[ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10),
                                                     SaveModelCallback(monitor='valid_loss', fname=f'{fname}_B{batch_size}_best')])
    
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    state_dict = torch.load(f'models/{fname}_B{batch_size}_best.pth')
    model.load_state_dict(state_dict)

    loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size, to_device=device)
    valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size, to_device=device)

    print(loss, valid_loss)

    predict = torch_predict([model.to(device)], x_test, batch_size, to_device=device)
    predict = np.reshape(predict, (-1))

    df = pd.read_csv('Database/sample_submission.csv', index_col=0)
    df['pressure'] = predict

    df.to_csv(f'Submission/{fname}_B{batch_size}.csv')

# %%
train_submission(epoch_num, batch_size)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.726833</td>
#       <td>1.839692</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.360153</td>
#       <td>1.108334</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.043722</td>
#       <td>0.968348</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.935002</td>
#       <td>0.918682</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.874883</td>
#       <td>0.865864</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.845298</td>
#       <td>0.815754</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.806134</td>
#       <td>0.792142</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.765273</td>
#       <td>0.753539</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.742960</td>
#       <td>0.720652</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.712467</td>
#       <td>0.704488</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.686127</td>
#       <td>0.676954</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.653811</td>
#       <td>0.634879</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.599928</td>
#       <td>0.603906</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.574379</td>
#       <td>0.574735</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.555300</td>
#       <td>0.563844</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.540999</td>
#       <td>0.533346</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.528920</td>
#       <td>0.528408</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.522459</td>
#       <td>0.499390</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.518391</td>
#       <td>0.513271</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.511538</td>
#       <td>0.505467</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.496333</td>
#       <td>0.507767</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.512450</td>
#       <td>0.482058</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.499313</td>
#       <td>0.491804</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.488500</td>
#       <td>0.487802</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.468982</td>
#       <td>0.487936</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.480058</td>
#       <td>0.500387</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.470323</td>
#       <td>0.490615</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.457896</td>
#       <td>0.451062</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.451511</td>
#       <td>0.453413</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.447443</td>
#       <td>0.458280</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.439973</td>
#       <td>0.425772</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.433729</td>
#       <td>0.468804</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.422195</td>
#       <td>0.437379</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.421717</td>
#       <td>0.413441</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.414453</td>
#       <td>0.438798</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.415403</td>
#       <td>0.395869</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.398167</td>
#       <td>0.398679</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.409612</td>
#       <td>0.381950</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.387192</td>
#       <td>0.374769</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.375682</td>
#       <td>0.375132</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.375364</td>
#       <td>0.376500</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.397756</td>
#       <td>0.379231</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.363031</td>
#       <td>0.353284</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.362483</td>
#       <td>0.361200</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.343754</td>
#       <td>0.324551</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.369172</td>
#       <td>0.348258</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.343838</td>
#       <td>0.354965</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.371429</td>
#       <td>0.373481</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.328562</td>
#       <td>0.324261</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.342858</td>
#       <td>0.350221</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.325943</td>
#       <td>0.325593</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.315900</td>
#       <td>0.318856</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.324274</td>
#       <td>0.308300</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.318997</td>
#       <td>0.322924</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.314487</td>
#       <td>0.315239</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.305111</td>
#       <td>0.401839</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.329425</td>
#       <td>0.323697</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.304339</td>
#       <td>0.311216</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.298387</td>
#       <td>0.297071</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.292806</td>
#       <td>0.297003</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.288417</td>
#       <td>0.296297</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.302644</td>
#       <td>0.339483</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.290816</td>
#       <td>0.302711</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.275785</td>
#       <td>0.320406</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.275217</td>
#       <td>0.299575</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.277889</td>
#       <td>0.307334</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.273936</td>
#       <td>0.305950</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.268392</td>
#       <td>0.261205</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.263637</td>
#       <td>0.268122</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.275849</td>
#       <td>0.260384</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.268440</td>
#       <td>0.269812</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.271235</td>
#       <td>0.276783</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.260837</td>
#       <td>0.289011</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.267406</td>
#       <td>0.286
# Better model found at epoch 0 with valid_loss value: 1.83969247341156.
# Better model found at epoch 1 with valid_loss value: 1.1083341836929321.
# Better model found at epoch 2 with valid_loss value: 0.9683480858802795.
# Better model found at epoch 3 with valid_loss value: 0.9186816811561584.
# Better model found at epoch 4 with valid_loss value: 0.8658638000488281.
# Better model found at epoch 5 with valid_loss value: 0.815754234790802.
# Better model found at epoch 6 with valid_loss value: 0.792141854763031.
# Better model found at epoch 7 with valid_loss value: 0.753538966178894.
# Better model found at epoch 8 with valid_loss value: 0.7206517457962036.
# Better model found at epoch 9 with valid_loss value: 0.7044875025749207.
# Better model found at epoch 10 with valid_loss value: 0.6769537329673767.
# Better model found at epoch 11 with valid_loss value: 0.634878933429718.
# Epoch 11: reducing lr to 1.676102095911848e-05
# Better model found at epoch 12 with valid_loss value: 0.6039060354232788.
# Better model found at epoch 13 with valid_loss value: 0.5747352838516235.
# Better model found at epoch 14 with valid_loss value: 0.5638442635536194.
# Better model found at epoch 15 with valid_loss value: 0.5333455204963684.
# Better model found at epoch 16 with valid_loss value: 0.528407633304596.
# Better model found at epoch 17 with valid_loss value: 0.4993901550769806.
# Better model found at epoch 21 with valid_loss value: 0.482058048248291.
# Epoch 22: reducing lr to 3.88927938420942e-05
# Better model found at epoch 27 with valid_loss value: 0.45106199383735657.
# Better model found at epoch 30 with valid_loss value: 0.42577213048934937.
# Epoch 32: reducing lr to 6.783323897900637e-05
# Better model found at epoch 33 with valid_loss value: 0.41344115138053894.
# Better model found at epoch 35 with valid_loss value: 0.39586859941482544.
# Better model found at epoch 37 with valid_loss value: 0.3819495737552643.
# Better model found at epoch 38 with valid_loss value: 0.3747692108154297.
# Better model found at epoch 42 with valid_loss value: 0.35328447818756104.
# Epoch 42: reducing lr to 0.00010138603335689133
# Better model found at epoch 44 with valid_loss value: 0.3245514929294586.
# Better model found at epoch 48 with valid_loss value: 0.324260950088501.
# Better model found at epoch 51 with valid_loss value: 0.3188563585281372.
# Better model found at epoch 52 with valid_loss value: 0.30830028653144836.
# Epoch 52: reducing lr to 0.0001352721790398354
# Better model found at epoch 58 with valid_loss value: 0.2970711588859558.
# Better model found at epoch 59 with valid_loss value: 0.2970026135444641.
# Better model found at epoch 60 with valid_loss value: 0.2962965965270996.
# Epoch 62: reducing lr to 0.00016517019894870903
# Better model found at epoch 67 with valid_loss value: 0.2612050175666809.
# Better model found at epoch 69 with valid_loss value: 0.2603839039802551.
# Epoch 72: reducing lr to 0.00018726715148379114
# Better model found at epoch 76 with valid_loss value: 0.2523609697818756.
# Better model found at epoch 81 with valid_loss value: 0.24056795239448547.
# Epoch 82: reducing lr to 0.0001987450238994892
# Better model found at epoch 83 with valid_loss value: 0.23871995508670807.
# Better model found at epoch 85 with valid_loss value: 0.23729927837848663.
# Better model found at epoch 91 with valid_loss value: 0.23287706077098846.
# Better model found at epoch 92 with valid_loss value: 0.2257973700761795.
# Epoch 92: reducing lr to 0.00019978410844857022
# Better model found at epoch 96 with valid_loss value: 0.22397316992282867.
# Better model found at epoch 97 with valid_loss value: 0.2226186990737915.
# Better model found at epoch 98 with valid_loss value: 0.2191825956106186.
# Better model found at epoch 102 with valid_loss value: 0.2125241607427597.
# Epoch 102: reducing lr to 0.00019828623597342496
# Better model found at epoch 103 with valid_loss value: 0.21212081611156464.
# Better model found at epoch 105 with valid_loss value: 0.2063024789094925.
# Epoch 112: reducing lr to 0.00019538228105635218
# Better model found at epoch 113 with valid_loss value: 0.20354047417640686.
# Better model found at epoch 119 with valid_loss value: 0.20078696310520172.
# Better model found at epoch 121 with valid_loss value: 0.19692173600196838.
# Epoch 122: reducing lr to 0.00019111378882406675
# Better model found at epoch 123 with valid_loss value: 0.19496780633926392.
# Better model found at epoch 128 with valid_loss value: 0.1881333738565445.
# Epoch 132: reducing lr to 0.00018554182306460083
# Better model found at epoch 136 with valid_loss value: 0.18465910851955414.
# Epoch 142: reducing lr to 0.00017874609783452236
# Better model found at epoch 149 with valid_loss value: 0.1838793307542801.
# Better model found at epoch 150 with valid_loss value: 0.1813230663537979.
# Better model found at epoch 151 with valid_loss value: 0.18067611753940582.
# Epoch 152: reducing lr to 0.0001708238337685183
# Better model found at epoch 153 with valid_loss value: 0.1793198585510254.
# Epoch 162: reducing lr to 0.00016188836425281406
# Better model found at epoch 166 with valid_loss value: 0.17629368603229523.
# Epoch 172: reducing lr to 0.00015206752839738903
# Better model found at epoch 175 with valid_loss value: 0.17539359629154205.
# Better model found at epoch 176 with valid_loss value: 0.1743909865617752.
# Better model found at epoch 179 with valid_loss value: 0.17425262928009033.
# Epoch 182: reducing lr to 0.00014150182120515093
# Better model found at epoch 191 with valid_loss value: 0.17355959117412567.
# Epoch 192: reducing lr to 0.0001303423972216955
# Better model found at epoch 195 with valid_loss value: 0.17339769005775452.
# Better model found at epoch 198 with valid_loss value: 0.1729937493801117.
# Epoch 202: reducing lr to 0.00011874890479148657
# Better model found at epoch 204 with valid_loss value: 0.1726042479276657.
# Better model found at epoch 207 with valid_loss value: 0.17256078124046326.
# Epoch 212: reducing lr to 0.00010688720210539318
# Better model found at epoch 213 with valid_loss value: 0.17224273085594177.
# Better model found at epoch 217 with valid_loss value: 0.17190533876419067.
# Epoch 222: reducing lr to 9.492699375978175e-05
# Epoch 232: reducing lr to 8.303936554592715e-05
# Epoch 242: reducing lr to 7.139439294440595e-05
# Epoch 252: reducing lr to 6.015867062891412e-05
# Epoch 262: reducing lr to 4.9492938478963534e-05
# Epoch 272: reducing lr to 3.9549782011760066e-05
# Epoch 282: reducing lr to 3.047144947157566e-05
# Epoch 292: reducing lr to 2.238781680565288e-05
# Epoch 302: reducing lr to 1.541452963999192e-05
# Epoch 312: reducing lr to 9.65134883618552e-06
# Epoch 322: reducing lr to 5.180723298006564e-06
# Epoch 332: reducing lr to 2.0666104453852597e-06
# Epoch 342: reducing lr to 3.535612302462028e-07
# 0.09078422693882958 0.17316127717494964
# prodict: 100% 99/99 [00:09<00:00, 10.66it/s]
# C:\users\ffly\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
