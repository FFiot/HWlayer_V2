# %%
import gc
import time
import argparse
from fastai.layers import swish

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter

from fastai.callback.schedule import Learner
from fastai.data.core import DataLoaders
from fastai.losses import L1LossFlat
from fastai.callback.core import Callback
from fastai.callback.tracker import ReduceLROnPlateau, SaveModelCallback

from HW_torch import dataLoads_build, net_parameter_count, hw_layer
from HW_base import evaluate_build, focus_build

# %%
fname               = 'F5_Linear-LSTM128x4-FC-SELU-FC'
epoch_num_first     = 100
batch_size_first    = 100
epoch_num_second    = 200
batch_size_second   = 1000
evaluate_num        = 128
focus_min           = 0.8

# %%
class net_test(torch.nn.Module):
    def __init__(self, **kwargs):
        super(net_test, self).__init__()
        self.embedding = torch.nn.Linear(5, 128, bias=False)
        self.lstm = torch.nn.LSTM(128, 128, num_layers=4, bias=False, bidirectional=True, batch_first=True)
        self.fc1 = torch.nn.Linear(128*2, 32, bias=False)
        self.selu = nn.SELU()
        self.fc2 = torch.nn.Linear(32, 1, bias=True)
    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc1(x)
        x = self.selu(x)
        x = self.fc2(x)
        return x

# %%
data_train_df = pd.read_csv('./Database/train.csv')
data_test_df = pd.read_csv('./Database/test.csv')

# %%
drop_columns = ['pressure','id', 'breath_id','one','count','breath_id_lag','breath_id_lag2','breath_id_lagsame','breath_id_lag2same','u_out_lag2']
x_columns = [col for col in data_train_df.columns if col not in drop_columns]
y_columns = ['pressure']

# %%
RS = RobustScaler()
data_train = data_train_df[x_columns].values.astype(np.float32)
data_train = RS.fit_transform(data_train)
data_train = data_train.reshape(-1, 80, data_train.shape[-1])

target_train = data_train_df[y_columns].values.astype(np.float32)
target_train = target_train.reshape(-1, 80, target_train.shape[-1])

data_test = data_test_df[x_columns].values.astype(np.float32)
data_test = RS.transform(data_test)
data_test = data_test.reshape(-1, 80, data_test.shape[-1])

# %%
np.random.seed(121212)
data_idx = np.arange(len(data_train))
np.random.shuffle(data_idx)

train_index = data_idx[:int(len(data_idx)*0.8)]
valid_index = data_idx[int(len(data_idx)*0.8):]

# %%
x_train, y_train = data_train[train_index], target_train[train_index]
x_valid, y_valid = data_train[valid_index], target_train[valid_index]
x_test = data_test

# %%
del data_train_df
del data_test_df
gc.collect()
# Out:
# 0

# %%
model = net_test()
print(model)

train_parameter_num, freeze_parameter_num = net_parameter_count(model)
print(train_parameter_num, freeze_parameter_num)
# Out:
# net_test(
#   (embedding): Linear(in_features=5, out_features=128, bias=False)
#   (lstm): LSTM(128, 128, num_layers=4, bias=False, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=256, out_features=32, bias=False)
#   (selu): SELU()
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
# 1450657 0

# %%
# state_dict = torch.load(f'models/{fname}_best.pth')
# model.load_state_dict(state_dict)

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_first)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_first, lr_max=2e-3, cbs=ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.077081</td>
#       <td>1.675194</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.023620</td>
#       <td>1.077236</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.930242</td>
#       <td>0.898507</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.846556</td>
#       <td>0.822920</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.731927</td>
#       <td>0.723377</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.692502</td>
#       <td>0.701418</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.644960</td>
#       <td>0.626696</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.651881</td>
#       <td>0.640965</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.592780</td>
#       <td>0.604848</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.549987</td>
#       <td>0.587266</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.525078</td>
#       <td>0.544369</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.518738</td>
#       <td>0.499063</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.486211</td>
#       <td>0.470484</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.468026</td>
#       <td>0.509690</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.445402</td>
#       <td>0.538724</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.435213</td>
#       <td>0.431118</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.422741</td>
#       <td>0.445687</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.419818</td>
#       <td>0.401281</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.418422</td>
#       <td>0.409633</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.400087</td>
#       <td>0.388425</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.392554</td>
#       <td>0.404530</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.398749</td>
#       <td>0.398860</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.358428</td>
#       <td>0.346132</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.383686</td>
#       <td>0.418907</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.365838</td>
#       <td>0.374469</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.335938</td>
#       <td>0.338290</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.356123</td>
#       <td>0.386493</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.324621</td>
#       <td>0.319347</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.355355</td>
#       <td>0.418622</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.312506</td>
#       <td>0.318083</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.317756</td>
#       <td>0.347379</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.303381</td>
#       <td>0.307232</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.301527</td>
#       <td>0.299639</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.288009</td>
#       <td>0.332387</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.284382</td>
#       <td>0.286998</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.291616</td>
#       <td>0.280573</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.277767</td>
#       <td>0.286107</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.265298</td>
#       <td>0.270793</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.291232</td>
#       <td>0.332722</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.264119</td>
#       <td>0.275240</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.257199</td>
#       <td>0.259157</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.258050</td>
#       <td>0.268695</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.262268</td>
#       <td>0.275079</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.255487</td>
#       <td>0.271685</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.248787</td>
#       <td>0.254313</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.249284</td>
#       <td>0.260119</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.235503</td>
#       <td>0.253168</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.241564</td>
#       <td>0.278769</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.232400</td>
#       <td>0.248074</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.233001</td>
#       <td>0.245515</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.220163</td>
#       <td>0.234283</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.221284</td>
#       <td>0.232684</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.235436</td>
#       <td>0.253468</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.248843</td>
#       <td>0.246346</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.221222</td>
#       <td>0.234765</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.212644</td>
#       <td>0.221857</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.207509</td>
#       <td>0.222779</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.211073</td>
#       <td>0.221288</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.200776</td>
#       <td>0.218334</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.206517</td>
#       <td>0.219949</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.197213</td>
#       <td>0.217124</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.198087</td>
#       <td>0.212199</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.200890</td>
#       <td>0.214803</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.193900</td>
#       <td>0.221173</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.186066</td>
#       <td>0.215329</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.201298</td>
#       <td>0.217012</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.194298</td>
#       <td>0.228140</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.181621</td>
#       <td>0.202553</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.178795</td>
#       <td>0.204156</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.177843</td>
#       <td>0.202148</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.174000</td>
#       <td>0.200504</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.168939</td>
#       <td>0.197906</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.173302</td>
#       <td>0.207155</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.168295</td>
#       <td>0.201
# Epoch 20: reducing lr to 0.00018811581420682857
# Epoch 30: reducing lr to 0.0001968600733474005
# Epoch 40: reducing lr to 0.0001783738672554453
# Epoch 50: reducing lr to 0.00014633629736660446
# Epoch 60: reducing lr to 0.00010628690715050083
# Epoch 70: reducing lr to 6.515063442816907e-05
# Epoch 80: reducing lr to 3.0040328534617842e-05
# Epoch 90: reducing lr to 7.026832443658031e-06

# %%
dataLoads = dataLoads_build(x_train, y_train, x_valid, y_valid, batch_size_second)
learn = Learner(dataLoads, model, loss_func=L1LossFlat())
learn.lr_find()
learn.fit_one_cycle(epoch_num_second, lr_max=2e-3, cbs=[ReduceLROnPlateau(monitor='valid_loss', min_delta=0.5, patience=10),
                                                        SaveModelCallback(monitor='valid_loss', fname=f'{fname}_best')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.138665</td>
#       <td>0.181263</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.138572</td>
#       <td>0.181261</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.138530</td>
#       <td>0.181303</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.138546</td>
#       <td>0.181230</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.138427</td>
#       <td>0.181447</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.138738</td>
#       <td>0.181318</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.138851</td>
#       <td>0.181410</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.138574</td>
#       <td>0.181289</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.138683</td>
#       <td>0.181349</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.138832</td>
#       <td>0.181279</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.138836</td>
#       <td>0.181896</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.138786</td>
#       <td>0.181947</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.139080</td>
#       <td>0.181311</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.139351</td>
#       <td>0.181818</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.139506</td>
#       <td>0.182076</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.139948</td>
#       <td>0.182146</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.139975</td>
#       <td>0.182746</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.140213</td>
#       <td>0.183644</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.140848</td>
#       <td>0.183453</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.140627</td>
#       <td>0.183986</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.140634</td>
#       <td>0.183488</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.141785</td>
#       <td>0.185576</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.141751</td>
#       <td>0.183839</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.141336</td>
#       <td>0.185850</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.141982</td>
#       <td>0.186596</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.143026</td>
#       <td>0.184092</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.142776</td>
#       <td>0.183433</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.142615</td>
#       <td>0.185660</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.143646</td>
#       <td>0.184816</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.144309</td>
#       <td>0.191401</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.146058</td>
#       <td>0.186725</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.149240</td>
#       <td>0.189972</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.147251</td>
#       <td>0.188126</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.146153</td>
#       <td>0.184923</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.145706</td>
#       <td>0.189747</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.146516</td>
#       <td>0.190669</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.145091</td>
#       <td>0.187031</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.145327</td>
#       <td>0.189844</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.149347</td>
#       <td>0.196476</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.150222</td>
#       <td>0.189015</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.148405</td>
#       <td>0.185389</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.146713</td>
#       <td>0.197179</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.148479</td>
#       <td>0.186578</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.150904</td>
#       <td>0.193636</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.150949</td>
#       <td>0.189165</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.148706</td>
#       <td>0.189884</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.149280</td>
#       <td>0.190044</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.148561</td>
#       <td>0.186627</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.149346</td>
#       <td>0.190137</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.150552</td>
#       <td>0.190949</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.156193</td>
#       <td>0.194547</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.154113</td>
#       <td>0.191284</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.151370</td>
#       <td>0.192614</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.150695</td>
#       <td>0.193518</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.148887</td>
#       <td>0.191901</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.151456</td>
#       <td>0.191654</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.149003</td>
#       <td>0.193386</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.147695</td>
#       <td>0.188692</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.147768</td>
#       <td>0.184670</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.145548</td>
#       <td>0.188570</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.144904</td>
#       <td>0.185581</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.145265</td>
#       <td>0.188998</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.150383</td>
#       <td>0.190136</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.151393</td>
#       <td>0.191025</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.148072</td>
#       <td>0.190207</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.145897</td>
#       <td>0.204457</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.144957</td>
#       <td>0.187193</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.143305</td>
#       <td>0.190705</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.147660</td>
#       <td>0.188947</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.147764</td>
#       <td>0.185473</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.145013</td>
#       <td>0.183889</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.142810</td>
#       <td>0.185518</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.142245</td>
#       <td>0.186974</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.141738</td>
#       <td>0.185
# Better model found at epoch 0 with valid_loss value: 0.18126346170902252.
# Better model found at epoch 1 with valid_loss value: 0.18126140534877777.
# Better model found at epoch 3 with valid_loss value: 0.18123021721839905.
# Epoch 10: reducing lr to 2.9967737103779228e-05
# Epoch 20: reducing lr to 8.003000730042371e-05
# Epoch 30: reducing lr to 0.00013924799608184903
# Epoch 40: reducing lr to 0.00018500244994715736
# Epoch 50: reducing lr to 0.00019997878165973243
# Epoch 60: reducing lr to 0.00019736575212051785
# Epoch 70: reducing lr to 0.0001904974131120252
# Epoch 80: reducing lr to 0.0001796739458424247
# Epoch 90: reducing lr to 0.00016536839801694806
# Epoch 100: reducing lr to 0.00014820596770888172
# Better model found at epoch 108 with valid_loss value: 0.18120735883712769.
# Epoch 110: reducing lr to 0.00012893674737234285
# Better model found at epoch 114 with valid_loss value: 0.18106544017791748.
# Better model found at epoch 115 with valid_loss value: 0.18079181015491486.
# Better model found at epoch 117 with valid_loss value: 0.17969001829624176.
# Epoch 120: reducing lr to 0.00010840292303861373
# Better model found at epoch 128 with valid_loss value: 0.1793147623538971.
# Better model found at epoch 129 with valid_loss value: 0.1792634278535843.
# Epoch 130: reducing lr to 8.750186718154809e-05
# Better model found at epoch 132 with valid_loss value: 0.17918552458286285.
# Better model found at epoch 134 with valid_loss value: 0.1791161745786667.
# Better model found at epoch 136 with valid_loss value: 0.17856428027153015.
# Better model found at epoch 140 with valid_loss value: 0.17832313477993011.
# Epoch 140: reducing lr to 6.714709267073658e-05
# Better model found at epoch 142 with valid_loss value: 0.17829011380672455.
# Better model found at epoch 149 with valid_loss value: 0.17809447646141052.
# Epoch 150: reducing lr to 4.8228191390209026e-05
# Better model found at epoch 158 with valid_loss value: 0.17795224487781525.
# Epoch 160: reducing lr to 3.157199635622084e-05
# Better model found at epoch 162 with valid_loss value: 0.1779053658246994.
# Better model found at epoch 163 with valid_loss value: 0.17784294486045837.
# Better model found at epoch 164 with valid_loss value: 0.17764593660831451.
# Epoch 170: reducing lr to 1.790650349719257e-05
# Better model found at epoch 172 with valid_loss value: 0.1776268482208252.
# Epoch 180: reducing lr to 7.828919987831295e-06
# Better model found at epoch 182 with valid_loss value: 0.17758473753929138.
# Epoch 190: reducing lr to 1.7796981872515628e-06

# %%
from HW_torch import torch_valid, torch_predict

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

state_dict = torch.load(f'models/{fname}_best.pth')
model.load_state_dict(state_dict)

loss = torch_valid([model.to(device)], L1LossFlat(), (x_train, y_train),  batch_size_second, to_device=device)
valid_loss = torch_valid([model.to(device)], L1LossFlat(), (x_valid, y_valid),  batch_size_second, to_device=device)

print(loss, valid_loss)
# Out:
# 0.108356203456394 0.17743553314357996

# %%
predict = torch_predict([model.to(device)], x_test, batch_size_second, to_device=device)
predict = np.reshape(predict, (-1))
# Out:
# prodict: 100% 51/51 [00:01<00:00, 25.82it/s]

# %%
df = pd.read_csv('Database/sample_submission.csv', index_col=0)
df['pressure'] = predict

df.to_csv(f'Submission/{fname}.csv')
# Out:
# C:\users\ffly\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
